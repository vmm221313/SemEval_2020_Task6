# %%
# %load main.py
import os
import torch
import pickle
import networkx as nx
from tqdm import tqdm_notebook

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
from GCN import gcn
from trainer import train
#from make_graph import build_graphs
from dataloader import graphs_dict_dataloader
from preprocess import load_and_preprocess
from load_graph_params import load_graph_params

# %%
df = load_and_preprocess()

# %%
num_adj = 3
num_output_classes = 2
embedding_dim = 1024
num_epochs = 1

# %%
weights_dict, word_embeddings, node_param, word_to_idx, weights_tuple_to_idx = load_graph_params()

# %%
graphs_dataset = graphs_dict_dataloader(df, num_adj, word_embeddings)

# trainloader = DataLoader(dataset = graphs_dataset, batch_size = 5)

# for x, y in trainloader:
#     print(x)
#     break

graphs_dataset[8]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('Using device - {}'.format(device))

model = gcn(num_output_classes, embedding_dim, node_param, weights_dict, word_embeddings)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

# +
#REINIT GRAPH WEIGHTS
# -

model, graphs = train(trainloader, df, model, loss_function, optimizer, num_epochs, weights_dict, word_embeddings, node_param, word_to_idx, weights_tuple_to_idx)

model



model.eval()

for i in tqdm_notebook(range(1000, 1100)):    
    graphs = get_message_and_update(i, graphs, word_embeddings, node_param, word_to_idx, weights_tuple_to_idx)
    with torch.no_grad():
        activated_out = model(graphs[i])
        print(activated_out)

activated_out

j = 0
for i in model.parameters():
    j+=1

len(weights_dict)

j

len(model.parameters())

# %%
from load_graph_params import load_graph_params

# %%
weights_dict, word_embeddings, node_param, word_to_idx, weights_tuple_to_idx = load_graph_params()

# %%
weights_dict
# Out:
# {'0': Parameter containing:
#  tensor([1.5820], requires_grad=True), '1': Parameter containing:
#  tensor([-0.5418], requires_grad=True), '2': Parameter containing:
#  tensor([-0.6761], requires_grad=True), '3': Parameter containing:
#  tensor([0.4269], requires_grad=True), '4': Parameter containing:
#  tensor([-0.7086], requires_grad=True), '5': Parameter containing:
#  tensor([-0.5324], requires_grad=True), '6': Parameter containing:
#  tensor([1.5631], requires_grad=True), '7': Parameter containing:
#  tensor([0.5860], requires_grad=True), '8': Parameter containing:
#  tensor([-0.1280], requires_grad=True), '9': Parameter containing:
#  tensor([1.7572], requires_grad=True), '10': Parameter containing:
#  tensor([0.4206], requires_grad=True), '11': Parameter containing:
#  tensor([-0.0743], requires_grad=True), '12': Parameter containing:
#  tensor([-2.3670], requires_grad=True), '13': Parameter containing:
#  tensor([-0.9531], requires_grad=True), '14': Parameter containing:
#  tensor([0.8358], requires_grad=True), '15': Parameter containing:
#  tensor([-0.4297], requires_grad=True), '16': Parameter containing:
#  tensor([0.0475], requires_grad=True), '17': Parameter containing:
#  tensor([-0.6875], requires_grad=True), '18': Parameter containing:
#  tensor([0.7897], requires_grad=True), '19': Parameter containing:
#  tensor([-1.1696], requires_grad=True), '20': Parameter containing:
#  tensor([0.9181], requires_grad=True), '21': Parameter containing:
#  tensor([0.1039], requires_grad=True), '22': Parameter containing:
#  tensor([-0.3794], requires_grad=True), '23': Parameter containing:
#  tensor([1.0282], requires_grad=True), '24': Parameter containing:
#  tensor([-0.8216], requires_grad=True), '25': Parameter containing:
#  tensor([0.4275], requires_grad=True), '26': Parameter containing:
#  tensor([1.7900], requires_grad=True), '27': Parameter containing:
#  tensor([1.8114], requires_grad=True), '28': Parameter containing:
#  tensor([0.2987], requires_grad=True), '29': Parameter containing:
#  tensor([1.5627], requires_grad=True), '30': Parameter containing:
#  tensor([-0.8799], requires_grad=True), '31': Parameter containing:
#  tensor([-1.2712], requires_grad=True), '32': Parameter containing:
#  tensor([0.0799], requires_grad=True), '33': Parameter containing:
#  tensor([-2.1727], requires_grad=True), '34': Parameter containing:
#  tensor([0.9213], requires_grad=True), '35': Parameter containing:
#  tensor([1.0763], requires_grad=True), '36': Parameter containing:
#  tensor([-0.2786], requires_grad=True), '37': Parameter containing:
#  tensor([0.6069], requires_grad=True), '38': Parameter containing:
#  tensor([-0.0923], requires_grad=True), '39': Parameter containing:
#  tensor([-0.4382], requires_grad=True), '40': Parameter containing:
#  tensor([-0.6830], requires_grad=True), '41': Parameter containing:
#  tensor([-1.4595], requires_grad=True), '42': Parameter containing:
#  tensor([0.9966], requires_grad=True), '43': Parameter containing:
#  tensor([0.6468], requires_grad=True), '44': Parameter containing:
#  tensor([-1.0760], requires_grad=True), '45': Parameter containing:
#  tensor([0.4234], requires_grad=True), '46': Parameter containing:
#  tensor([0.1066], requires_grad=True), '47': Parameter containing:
#  tensor([0.5538], requires_grad=True), '48': Parameter containing:
#  tensor([0.5002], requires_grad=True), '49': Parameter containing:
#  tensor([1.2495], requires_grad=True), '50': Parameter containing:
#  tensor([0.1692], requires_grad=True), '51': Parameter containing:
#  tensor([0.5984], requires_grad=True), '52': Parameter containing:
#  tensor([-2.0631], requires_grad=True), '53': Parameter containing:
#  tensor([1.3804], requires_grad=True), '54': Parameter containing:
#  tensor([-0.0950], requires_grad=True), '55': Parameter containing:
#  tensor([0.0151], requires_grad=True), '56': Parameter containing:
#  tensor([1.1556], requires_grad=True), '57': Parameter containing:
#  tensor([0.3762], requires_grad=True), '58': Parameter containing:
#  tensor([0.2561], requires_grad=True), '59': Parameter containing:
#  tensor([-0.0192], requires_grad=True), '60': Parameter containing:
#  tensor([-0.3125], requires_grad=True), '61': Parameter containing:
#  tensor([-0.7914], requires_grad=True), '62': Parameter containing:
#  tensor([-0.2416], requires_grad=True), '63': Parameter containing:
#  tensor([0.4214], requires_grad=True), '64': Parameter containing:
#  tensor([1.2307], requires_grad=True), '65': Parameter containing:
#  tensor([0.7458], requires_grad=True), '66': Parameter containing:
#  tensor([0.9490], requires_grad=True), '67': Parameter containing:
#  tensor([1.4577], requires_grad=True), '68': Parameter containing:
#  tensor([1.7914], requires_grad=True), '69': Parameter containing:
#  tensor([0.7184], requires_grad=True), '70': Parameter containing:
#  tensor([0.5224], requires_grad=True), '71': Parameter containing:
#  tensor([1.1299], requires_grad=True), '72': Parameter containing:
#  tensor([-1.3227], requires_grad=True), '73': Parameter containing:
#  tensor([-0.6780], requires_grad=True), '74': Parameter containing:
#  tensor([-0.2310], requires_grad=True), '75': Parameter containing:
#  tensor([1.5760], requires_grad=True), '76': Parameter containing:
#  tensor([-0.5594], requires_grad=True), '77': Parameter containing:
#  tensor([-2.0391], requires_grad=True), '78': Parameter containing:
#  tensor([-1.0343], requires_grad=True), '79': Parameter containing:
#  tensor([0.6058], requires_grad=True), '80': Parameter containing:
#  tensor([1.4019], requires_grad=True), '81': Parameter containing:
#  tensor([1.4087], requires_grad=True), '82': Parameter containing:
#  tensor([-0.2619], requires_grad=True), '83': Parameter containing:
#  tensor([-0.2334], requires_grad=True), '84': Parameter containing:
#  tensor([-0.2921], requires_grad=True), '85': Parameter containing:
#  tensor([0.3443], requires_grad=True), '86': Parameter containing:
#  tensor([-1.6483], requires_grad=True), '87': Parameter containing:
#  tensor([0.0737], requires_grad=True), '88': Parameter containing:
#  tensor([1.2322], requires_grad=True), '89': Parameter containing:
#  tensor([0.7613], requires_grad=True), '90': Parameter containing:
#  tensor([0.8314], requires_grad=True), '91': Parameter containing:
#  tensor([0.4112], requires_grad=True), '92': Parameter containing:
#  tensor([0.6632], requires_grad=True), '93': Parameter containing:
#  tensor([1.0152], requires_grad=True), '94': Parameter containing:
#  tensor([1.9324], requires_grad=True), '95': Parameter containing:
#  tensor([1.1870], requires_grad=True), '96': Parameter containing:
#  tensor([0.2743], requires_grad=True), '97': Parameter containing:
#  tensor([-0.6447], requires_grad=True), '98': Parameter containing:
#  tensor([0.0651], requires_grad=True), '99': Parameter containing:
#  tensor([0.9681], requires_grad=True), '100': Parameter containing:
#  tensor([-1.7085], requires_grad=True), '101': Parameter containing:
#  tensor([0.1151], requires_grad=True), '102': Parameter containing:
#  tensor([-1.1264], requires_grad=True), '103': Parameter containing:
#  tensor([1.3199], requires_grad=True), '104': Parameter containing:
#  tensor([-0.3097], requires_grad=True), '105': Parameter containing:
#  tensor([1.0336], requires_grad=True), '106': Parameter containing:
#  tensor([-0.3933], requires_grad=True), '107': Parameter containing:
#  tensor([-0.8343], requires_grad=True), '108': Parameter containing:
#  tensor([-1.2300], requires_grad=True), '109': Parameter containing:
#  tensor([0.4262], requires_grad=True), '110': Parameter containing:
#  tensor([-0.6354], requires_grad=True), '111': Parameter containing:
#  tensor([-1.3621], requires_grad=True), '112': Parameter containing:
#  tensor([-0.0314], requires_grad=True), '113': Parameter containing:
#  tensor([1.3016], requires_grad=True), '114': Parameter containing:
#  tensor([0.9455], requires_grad=True), '115': Parameter containing:
#  tensor([0.7441], requires_grad=True), '116': Parameter containing:
#  tensor([-0.5500], requires_grad=True), '117': Parameter containing:
#  tensor([0.3242], requires_grad=True), '118': Parameter containing:
#  tensor([0.3188], requires_grad=True), '119': Parameter containing:
#  tensor([0.7613], requires_grad=True), '120': Parameter containing:
#  tensor([-1.6020], requires_grad=True), '121': Parameter containing:
#  tensor([0.1183], requires_grad=True), '122': Parameter containing:
#  tensor([-0.8927], requires_grad=True), '123': Parameter containing:
#  tensor([-0.1203], requires_grad=True), '124': Parameter containing:
#  tensor([-0.5484], requires_grad=True), '125': Parameter containing:
#  tensor([0.0093], requires_grad=True), '126': Parameter containing:
#  tensor([0.0393], requires_grad=True), '127': Parameter containing:
#  tensor([1.9497], requires_grad=True), '128': Parameter containing:
#  tensor([-0.8497], requires_grad=True), '129': Parameter containing:
#  tensor([1.2584], requires_grad=True), '130': Parameter containing:
#  tensor([-0.2834], requires_grad=True), '131': Parameter containing:
#  tensor([0.9351], requires_grad=True), '132': Parameter containing:
#  tensor([-0.9192], requires_grad=True), '133': Parameter containing:
#  tensor([0.3401], requires_grad=True), '134': Parameter containing:
#  tensor([1.1142], requires_grad=True), '135': Parameter containing:
#  tensor([0.0732], requires_grad=True), '136': Parameter containing:
#  tensor([-1.4789], requires_grad=True), '137': Parameter containing:
#  tensor([-0.7785], requires_grad=True), '138': Parameter containing:
#  tensor([0.8811], requires_grad=True), '139': Parameter containing:
#  tensor([1.7276], requires_grad=True), '140': Parameter containing:
#  tensor([1.5551], requires_grad=True), '141': Parameter containing:
#  tensor([0.7048], requires_grad=True), '142': Parameter containing:
#  tensor([-0.2484], requires_grad=True), '143': Parameter containing:
#  tensor([-0.8968], requires_grad=True), '144': Parameter containing:
#  tensor([-1.8308], requires_grad=True), '145': Parameter containing:
#  tensor([-0.8095], requires_grad=True), '146': Parameter containing:
#  tensor([-0.1681], requires_grad=True), '147': Parameter containing:
#  tensor([1.9161], requires_grad=True), '148': Parameter containing:
#  tensor([-1.3869], requires_grad=True), '149': Parameter containing:
#  tensor([2.0525], requires_grad=True), '150': Parameter containing:
#  tensor([-0.1343], requires_grad=True), '151': Parameter containing:
#  tensor([-0.6344], requires_grad=True), '152': Parameter containing:
#  tensor([-0.7271], requires_grad=True), '153': Parameter containing:
#  tensor([-0.4991], requires_grad=True), '154': Parameter containing:
#  tensor([1.3127], requires_grad=True), '155': Parameter containing:
#  tensor([-0.5958], requires_grad=True), '156': Parameter containing:
#  tensor([-0.5303], requires_grad=True), '157': Parameter containing:
#  tensor([0.9969], requires_grad=True), '158': Parameter containing:
#  tensor([-0.3433], requires_grad=True), '159': Parameter containing:
#  tensor([-0.0445], requires_grad=True), '160': Parameter containing:
#  tensor([0.5604], requires_grad=True), '161': Parameter containing:
#  tensor([0.8713], requires_grad=True), '162': Parameter containing:
#  tensor([1.4668], requires_grad=True), '163': Parameter containing:
#  tensor([1.2129], requires_grad=True), '164': Parameter containing:
#  tensor([-1.6003], requires_grad=True), '165': Parameter containing:
#  tensor([1.3104], requires_grad=True), '166': Parameter containing:
#  tensor([-0.3713], requires_grad=True), '167': Parameter containing:
#  tensor([2.0235], requires_grad=True), '168': Parameter containing:
#  tensor([-0.6678], requires_grad=True), '169': Parameter containing:
#  tensor([0.8676], requires_grad=True), '170': Parameter containing:
#  tensor([1.7062], requires_grad=True), '171': Parameter containing:
#  tensor([-0.5874], requires_grad=True), '172': Parameter containing:
#  tensor([-1.0083], requires_grad=True), '173': Parameter containing:
#  tensor([-0.5970], requires_grad=True), '174': Parameter containing:
#  tensor([-0.0838], requires_grad=True), '175': Parameter containing:
#  tensor([0.3951], requires_grad=True), '176': Parameter containing:
#  tensor([-0.3289], requires_grad=True), '177': Parameter containing:
#  tensor([-1.6664], requires_grad=True), '178': Parameter containing:
#  tensor([0.6493], requires_grad=True), '179': Parameter containing:
#  tensor([-0.6939], requires_grad=True), '180': Parameter containing:
#  tensor([-1.0160], requires_grad=True), '181': Parameter containing:
#  tensor([1.2908], requires_grad=True), '182': Parameter containing:
#  tensor([0.2520], requires_grad=True), '183': Parameter containing:
#  tensor([-0.1964], requires_grad=True), '184': Parameter containing:
#  tensor([-0.1158], requires_grad=True), '185': Parameter containing:
#  tensor([-0.4838], requires_grad=True), '186': Parameter containing:
#  tensor([0.7589], requires_grad=True), '187': Parameter containing:
#  tensor([0.9249], requires_grad=True), '188': Parameter containing:
#  tensor([-1.0882], requires_grad=True), '189': Parameter containing:
#  tensor([-0.1706], requires_grad=True), '190': Parameter containing:
#  tensor([0.3726], requires_grad=True), '191': Parameter containing:
#  tensor([0.7709], requires_grad=True), '192': Parameter containing:
#  tensor([-2.0867], requires_grad=True), '193': Parameter containing:
#  tensor([-0.5213], requires_grad=True), '194': Parameter containing:
#  tensor([0.3990], requires_grad=True), '195': Parameter containing:
#  tensor([0.9151], requires_grad=True), '196': Parameter containing:
#  tensor([-0.2168], requires_grad=True), '197': Parameter containing:
#  tensor([-0.2889], requires_grad=True), '198': Parameter containing:
#  tensor([-1.3728], requires_grad=True), '199': Parameter containing:
#  tensor([-0.2527], requires_grad=True), '200': Parameter containing:
#  tensor([0.0208], requires_grad=True), '201': Parameter containing:
#  tensor([1.8372], requires_grad=True), '202': Parameter containing:
#  tensor([-0.2284], requires_grad=True), '203': Parameter containing:
#  tensor([1.2029], requires_grad=True), '204': Parameter containing:
#  tensor([-1.4723], requires_grad=True), '205': Parameter containing:
#  tensor([1.5068], requires_grad=True), '206': Parameter containing:
#  tensor([-0.2908], requires_grad=True), '207': Parameter containing:
#  tensor([0.2144], requires_grad=True), '208': Parameter containing:
#  tensor([0.3953], requires_grad=True), '209': Parameter containing:
#  tensor([-1.6581], requires_grad=True), '210': Parameter containing:
#  tensor([-0.9747], requires_grad=True), '211': Parameter containing:
#  tensor([1.2027], requires_grad=True), '212': Parameter containing:
#  tensor([-1.1265], requires_grad=True), '213': Parameter containing:
#  tensor([-0.5514], requires_grad=True), '214': Parameter containing:
#  tensor([0.8022], requires_grad=True), '215': Parameter containing:
#  tensor([0.5275], requires_grad=True), '216': Parameter containing:
#  tensor([-0.5222], requires_grad=True), '217': Parameter containing:
#  tensor([-0.1696], requires_grad=True), '218': Parameter containing:
#  tensor([0.1853], requires_grad=True), '219': Parameter containing:
#  tensor([-0.5845], requires_grad=True), '220': Parameter containing:
#  tensor([-0.1580], requires_grad=True), '221': Parameter containing:
#  tensor([0.6071], requires_grad=True), '222': Parameter containing:
#  tensor([1.0107], requires_grad=True), '223': Parameter containing:
#  tensor([-0.5044], requires_grad=True), '224': Parameter containing:
#  tensor([-0.0089], requires_grad=True), '225': Parameter containing:
#  tensor([-1.0385], requires_grad=True), '226': Parameter containing:
#  tensor([-1.9814], requires_grad=True), '227': Parameter containing:
#  tensor([-0.0396], requires_grad=True), '228': Parameter containing:
#  tensor([0.9803], requires_grad=True), '229': Parameter containing:
#  tensor([0.6779], requires_grad=True), '230': Parameter containing:
#  tensor([0.1708], requires_grad=True), '231': Parameter containing:
#  tensor([-0.3285], requires_grad=True), '232': Parameter containing:
#  tensor([-0.1312], requires_grad=True), '233': Parameter containing:
#  tensor([-0.4736], requires_grad=True), '234': Parameter containing:
#  tensor([-1.0645], requires_grad=True), '235': Parameter containing:
#  tensor([-0.0178], requires_grad=True), '236': Parameter containing:
#  tensor([-0.0687], requires_grad=True), '237': Parameter containing:
#  tensor([0.1833], requires_grad=True), '238': Parameter containing:
#  tensor([-0.5912], requires_grad=True), '239': Parameter containing:
#  tensor([-0.4612], requires_grad=True), '240': Parameter containing:
#  tensor([0.5436], requires_grad=True), '241': Parameter containing:
#  tensor([-2.0909], requires_grad=True), '242': Parameter containing:
#  tensor([-1.0283], requires_grad=True), '243': Parameter containing:
#  tensor([-0.5854], requires_grad=True), '244': Parameter containing:
#  tensor([0.8604], requires_grad=True), '245': Parameter containing:
#  tensor([0.5583], requires_grad=True), '246': Parameter containing:
#  tensor([0.8222], requires_grad=True), '247': Parameter containing:
#  tensor([-0.7183], requires_grad=True), '248': Parameter containing:
#  tensor([-0.4956], requires_grad=True), '249': Parameter containing:
#  tensor([-0.0454], requires_grad=True), '250': Parameter containing:
#  tensor([0.7323], requires_grad=True), '251': Parameter containing:
#  tensor([-0.9212], requires_grad=True), '252': Parameter containing:
#  tensor([-0.1510], requires_grad=True), '253': Parameter containing:
#  tensor([-1.1817], requires_grad=True), '254': Parameter containing:
#  tensor([-0.1641], requires_grad=True), '255': Parameter containing:
#  tensor([-0.6966], requires_grad=True), '256': Parameter containing:
#  tensor([0.0183], requires_grad=True), '257': Parameter containing:
#  tensor([0.6976], requires_grad=True), '258': Parameter containing:
#  tensor([-0.6783], requires_grad=True), '259': Parameter containing:
#  tensor([1.4538], requires_grad=True), '260': Parameter containing:
#  tensor([-1.3060], requires_grad=True), '261': Parameter containing:
#  tensor([-1.4758], requires_grad=True), '262': Parameter containing:
#  tensor([-0.9640], requires_grad=True), '263': Parameter containing:
#  tensor([0.0211], requires_grad=True), '264': Parameter containing:
#  tensor([0.6295], requires_grad=True), '265': Parameter containing:
#  tensor([0.3993], requires_grad=True), '266': Parameter containing:
#  tensor([-1.3913], requires_grad=True), '267': Parameter containing:
#  tensor([-0.9781], requires_grad=True), '268': Parameter containing:
#  tensor([1.9181], requires_grad=True), '269': Parameter containing:
#  tensor([0.0530], requires_grad=True), '270': Parameter containing:
#  tensor([-0.6289], requires_grad=True), '271': Parameter containing:
#  tensor([1.0013], requires_grad=True), '272': Parameter containing:
#  tensor([-0.1986], requires_grad=True), '273': Parameter containing:
#  tensor([0.4660], requires_grad=True), '274': Parameter containing:
#  tensor([0.0570], requires_grad=True), '275': Parameter containing:
#  tensor([-0.3144], requires_grad=True), '276': Parameter containing:
#  tensor([-1.0843], requires_grad=True), '277': Parameter containing:
#  tensor([1.8054], requires_grad=True), '278': Parameter containing:
#  tensor([-0.6433], requires_grad=True), '279': Parameter containing:
#  tensor([-1.5473], requires_grad=True), '280': Parameter containing:
#  tensor([1.1482], requires_grad=True), '281': Parameter containing:
#  tensor([-0.0389], requires_grad=True), '282': Parameter containing:
#  tensor([-0.7944], requires_grad=True), '283': Parameter containing:
#  tensor([-0.6176], requires_grad=True), '284': Parameter containing:
#  tensor([-0.5264], requires_grad=True), '285': Parameter containing:
#  tensor([0.1731], requires_grad=True), '286': Parameter containing:
#  tensor([1.7243], requires_grad=True), '287': Parameter containing:
#  tensor([-1.4565], requires_grad=True), '288': Parameter containing:
#  tensor([0.6462], requires_grad=True), '289': Parameter containing:
#  tensor([-0.3792], requires_grad=True), '290': Parameter containing:
#  tensor([-0.4920], requires_grad=True), '291': Parameter containing:
#  tensor([-0.0204], requires_grad=True), '292': Parameter containing:
#  tensor([1.0702], requires_grad=True), '293': Parameter containing:
#  tensor([0.0516], requires_grad=True), '294': Parameter containing:
#  tensor([0.4942], requires_grad=True), '295': Parameter containing:
#  tensor([-0.2882], requires_grad=True), '296': Parameter containing:
#  tensor([-1.6137], requires_grad=True), '297': Parameter containing:
#  tensor([0.1524], requires_grad=True), '298': Parameter containing:
#  tensor([-0.3047], requires_grad=True), '299': Parameter containing:
#  tensor([-1.2825], requires_grad=True), '300': Parameter containing:
#  tensor([2.1926], requires_grad=True), '301': Parameter containing:
#  tensor([-1.9935], requires_grad=True), '302': Parameter containing:
#  tensor([-0.7177], requires_grad=True), '303': Parameter containing:
#  tensor([0.2003], requires_grad=True), '304': Parameter containing:
#  tensor([0.7897], requires_grad=True), '305': Parameter containing:
#  tensor([1.5163], requires_grad=True), '306': Parameter containing:
#  tensor([1.2320], requires_grad=True), '307': Parameter containing:
#  tensor([-1.4287], requires_grad=True), '308': Parameter containing:
#  tensor([-1.0205], requires_grad=True), '309': Parameter containing:
#  tensor([-0.8726], requires_grad=True), '310': Parameter containing:
#  tensor([-0.9216], requires_grad=True), '311': Parameter containing:
#  tensor([0.3371], requires_grad=True), '312': Parameter containing:
#  tensor([0.3464], requires_grad=True), '313': Parameter containing:
#  tensor([0.0285], requires_grad=True), '314': Parameter containing:
#  tensor([-0.1946], requires_grad=True), '315': Parameter containing:
#  tensor([0.1456], requires_grad=True), '316': Parameter containing:
#  tensor([0.6280], requires_grad=True), '317': Parameter containing:
#  tensor([0.3921], requires_grad=True), '318': Parameter containing:
#  tensor([0.0390], requires_grad=True), '319': Parameter containing:
#  tensor([0.2174], requires_grad=True), '320': Parameter containing:
#  tensor([-1.1567], requires_grad=True), '321': Parameter containing:
#  tensor([-0.0436], requires_grad=True), '322': Parameter containing:
#  tensor([0.7910], requires_grad=True), '323': Parameter containing:
#  tensor([0.3341], requires_grad=True), '324': Parameter containing:
#  tensor([-0.9673], requires_grad=True), '325': Parameter containing:
#  tensor([0.4765], requires_grad=True), '326': Parameter containing:
#  tensor([-1.7351], requires_grad=True), '327': Parameter containing:
#  tensor([-1.4846], requires_grad=True), '328': Parameter containing:
#  tensor([1.5591], requires_grad=True), '329': Parameter containing:
#  tensor([0.2359], requires_grad=True), '330': Parameter containing:
#  tensor([-0.3589], requires_grad=True), '331': Parameter containing:
#  tensor([0.3628], requires_grad=True), '332': Parameter containing:
#  tensor([-0.7068], requires_grad=True), '333': Parameter containing:
#  tensor([-0.4272], requires_grad=True), '334': Parameter containing:
#  tensor([-0.1895], requires_grad=True), '335': Parameter containing:
#  tensor([0.2434], requires_grad=True), '336': Parameter containing:
#  tensor([-2.4020], requires_grad=True), '337': Parameter containing:
#  tensor([0.1672], requires_grad=True), '338': Parameter containing:
#  tensor([1.6091], requires_grad=True), '339': Parameter containing:
#  tensor([1.0113], requires_grad=True), '340': Parameter containing:
#  tensor([0.3032], requires_grad=True), '341': Parameter containing:
#  tensor([0.6653], requires_grad=True), '342': Parameter containing:
#  tensor([0.1329], requires_grad=True), '343': Parameter containing:
#  tensor([-1.2927], requires_grad=True), '344': Parameter containing:
#  tensor([-1.4450], requires_grad=True), '345': Parameter containing:
#  tensor([0.5984], requires_grad=True), '346': Parameter containing:
#  tensor([-0.1369], requires_grad=True), '347': Parameter containing:
#  tensor([1.2565], requires_grad=True), '348': Parameter containing:
#  tensor([2.6395], requires_grad=True), '349': Parameter containing:
#  tensor([-0.7778], requires_grad=True), '350': Parameter containing:
#  tensor([0.9243], requires_grad=True), '351': Parameter containing:
#  tensor([0.9366], requires_grad=True), '352': Parameter containing:
#  tensor([-0.7267], requires_grad=True), '353': Parameter containing:
#  tensor([-1.2161], requires_grad=True), '354': Parameter containing:
#  tensor([0.3745], requires_grad=True), '355': Parameter containing:
#  tensor([-0.7136], requires_grad=True), '356': Parameter containing:
#  tensor([0.5585], requires_grad=True), '357': Parameter containing:
#  tensor([0.0073], requires_grad=True), '358': Parameter containing:
#  tensor([-0.2851], requires_grad=True), '359': Parameter containing:
#  tensor([-0.5464], requires_grad=True), '360': Parameter containing:
#  tensor([-1.2711], requires_grad=True), '361': Parameter containing:
#  tensor([0.5450], requires_grad=True), '362': Parameter containing:
#  tensor([0.1724], requires_grad=True), '363': Parameter containing:
#  tensor([-1.2732], requires_grad=True), '364': Parameter containing:
#  tensor([0.5554], requires_grad=True), '365': Parameter containing:
#  tensor([-1.3400], requires_grad=True), '366': Parameter containing:
#  tensor([0.4107], requires_grad=True), '367': Parameter containing:
#  tensor([-0.4751], requires_grad=True), '368': Parameter containing:
#  tensor([0.6990], requires_grad=True), '369': Parameter containing:
#  tensor([0.6856], requires_grad=True), '370': Parameter containing:
#  tensor([0.9801], requires_grad=True), '371': Parameter containing:
#  tensor([1.6078], requires_grad=True), '372': Parameter containing:
#  tensor([-1.1155], requires_grad=True), '373': Parameter containing:
#  tensor([0.0834], requires_grad=True), '374': Parameter containing:
#  tensor([0.4053], requires_grad=True), '375': Parameter containing:
#  tensor([-1.2022], requires_grad=True), '376': Parameter containing:
#  tensor([1.5315], requires_grad=True), '377': Parameter containing:
#  tensor([0.4043], requires_grad=True), '378': Parameter containing:
#  tensor([0.4856], requires_grad=True), '379': Parameter containing:
#  tensor([1.1060], requires_grad=True), '380': Parameter containing:
#  tensor([-1.0549], requires_grad=True), '381': Parameter containing:
#  tensor([-1.3438], requires_grad=True), '382': Parameter containing:
#  tensor([0.5629], requires_grad=True), '383': Parameter containing:
#  tensor([-0.7947], requires_grad=True), '384': Parameter containing:
#  tensor([0.5020], requires_grad=True), '385': Parameter containing:
#  tensor([0.5721], requires_grad=True), '386': Parameter containing:
#  tensor([2.1760], requires_grad=True), '387': Parameter containing:
#  tensor([0.1652], requires_grad=True), '388': Parameter containing:
#  tensor([-1.0400], requires_grad=True), '389': Parameter containing:
#  tensor([-0.4389], requires_grad=True), '390': Parameter containing:
#  tensor([-0.8959], requires_grad=True), '391': Parameter containing:
#  tensor([-0.0723], requires_grad=True), '392': Parameter containing:
#  tensor([-0.1763], requires_grad=True), '393': Parameter containing:
#  tensor([0.6369], requires_grad=True), '394': Parameter containing:
#  tensor([-1.3135], requires_grad=True), '395': Parameter containing:
#  tensor([0.9224], requires_grad=True), '396': Parameter containing:
#  tensor([1.4241], requires_grad=True), '397': Parameter containing:
#  tensor([0.3799], requires_grad=True), '398': Parameter containing:
#  tensor([-1.4831], requires_grad=True), '399': Parameter containing:
#  tensor([0.5129], requires_grad=True), '400': Parameter containing:
#  tensor([1.1651], requires_grad=True), '401': Parameter containing:
#  tensor([-1.0952], requires_grad=True), '402': Parameter containing:
#  tensor([-1.9257], requires_grad=True), '403': Parameter containing:
#  tensor([0.5429], requires_grad=True), '404': Parameter containing:
#  tensor([-0.2575], requires_grad=True), '405': Parameter containing:
#  tensor([0.9011], requires_grad=True), '406': Parameter containing:
#  tensor([-0.3261], requires_grad=True), '407': Parameter containing:
#  tensor([1.2829], requires_grad=True), '408': Parameter containing:
#  tensor([0.9784], requires_grad=True), '409': Parameter containing:
#  tensor([1.1252], requires_grad=True), '410': Parameter containing:
#  tensor([1.0196], requires_grad=True), '411': Parameter containing:
#  tensor([0.6768], requires_grad=True), '412': Parameter containing:
#  tensor([1.2349], requires_grad=True), '413': Parameter containing:
#  tensor([1.7859], requires_grad=True), '414': Parameter containing:
#  tensor([-1.9666], requires_grad=True), '415': Parameter containing:
#  tensor([1.1815], requires_grad=True), '416': Parameter containing:
#  tensor([1.2320], requires_grad=True), '417': Parameter containing:
#  tensor([-1.2586], requires_grad=True), '418': Parameter containing:
#  tensor([-0.9279], requires_grad=True), '419': Parameter containing:
#  tensor([-0.6889], requires_grad=True), '420': Parameter containing:
#  tensor([0.4273], requires_grad=True), '421': Parameter containing:
#  tensor([0.5842], requires_grad=True), '422': Parameter containing:
#  tensor([-0.8137], requires_grad=True), '423': Parameter containing:
#  tensor([-1.4237], requires_grad=True), '424': Parameter containing:
#  tensor([0.4922], requires_grad=True), '425': Parameter containing:
#  tensor([0.8216], requires_grad=True), '426': Parameter containing:
#  tensor([0.7518], requires_grad=True), '427': Parameter containing:
#  tensor([-0.4347], requires_grad=True), '428': Parameter containing:
#  tensor([-0.9815], requires_grad=True), '429': Parameter containing:
#  tensor([-0.8515], requires_grad=True), '430': Parameter containing:
#  tensor([1.7351], requires_grad=True), '431': Parameter containing:
#  tensor([0.5468], requires_grad=True), '432': Parameter containing:
#  tensor([-1.2592], requires_grad=True), '433': Parameter containing:
#  tensor([0.3717], requires_grad=True), '434': Parameter containing:
#  tensor([0.4886], requires_grad=True), '435': Parameter containing:
#  tensor([0.0577], requires_grad=True), '436': Parameter containing:
#  tensor([0.5892], requires_grad=True), '437': Parameter containing:
#  tensor([1.0700], requires_grad=True), '438': Parameter containing:
#  tensor([0.7151], requires_grad=True), '439': Parameter containing:
#  tensor([1.1441], requires_grad=True), '440': Parameter containing:
#  tensor([0.9719], requires_grad=True), '441': Parameter containing:
#  tensor([-0.7804], requires_grad=True), '442': Parameter containing:
#  tensor([-1.3388], requires_grad=True), '443': Parameter containing:
#  tensor([1.7893], requires_grad=True), '444': Parameter containing:
#  tensor([-0.2530], requires_grad=True), '445': Parameter containing:
#  tensor([1.7231], requires_grad=True), '446': Parameter containing:
#  tensor([-0.8007], requires_grad=True), '447': Parameter containing:
#  tensor([1.0249], requires_grad=True), '448': Parameter containing:
#  tensor([-0.6025], requires_grad=True), '449': Parameter containing:
#  tensor([-1.8986], requires_grad=True), '450': Parameter containing:
#  tensor([0.6133], requires_grad=True), '451': Parameter containing:
#  tensor([-1.0635], requires_grad=True), '452': Parameter containing:
#  tensor([-1.0437], requires_grad=True), '453': Parameter containing:
#  tensor([-0.3001], requires_grad=True), '454': Parameter containing:
#  tensor([0.4210], requires_grad=True), '455': Parameter containing:
#  tensor([0.2854], requires_grad=True), '456': Parameter containing:
#  tensor([1.3524], requires_grad=True), '457': Parameter containing:
#  tensor([1.8653], requires_grad=True), '458': Parameter containing:
#  tensor([-2.0007], requires_grad=True), '459': Parameter containing:
#  tensor([-0.1575], requires_grad=True), '460': Parameter containing:
#  tensor([-1.3419], requires_grad=True), '461': Parameter containing:
#  tensor([0.3207], requires_grad=True), '462': Parameter containing:
#  tensor([-0.9606], requires_grad=True), '463': Parameter containing:
#  tensor([1.4952], requires_grad=True), '464': Parameter containing:
#  tensor([-0.9021], requires_grad=True), '465': Parameter containing:
#  tensor([-1.2158], requires_grad=True), '466': Parameter containing:
#  tensor([-0.2273], requires_grad=True), '467': Parameter containing:
#  tensor([0.3413], requires_grad=True), '468': Parameter containing:
#  tensor([2.3019], requires_grad=True), '469': Parameter containing:
#  tensor([-0.1445], requires_grad=True), '470': Parameter containing:
#  tensor([0.6961], requires_grad=True), '471': Parameter containing:
#  tensor([-1.0632], requires_grad=True), '472': Parameter containing:
#  tensor([-0.4243], requires_grad=True), '473': Parameter containing:
#  tensor([-0.2998], requires_grad=True), '474': Parameter containing:
#  tensor([0.7637], requires_grad=True), '475': Parameter containing:
#  tensor([-0.2320], requires_grad=True), '476': Parameter containing:
#  tensor([1.0732], requires_grad=True), '477': Parameter containing:
#  tensor([-0.4417], requires_grad=True), '478': Parameter containing:
#  tensor([-0.6059], requires_grad=True), '479': Parameter containing:
#  tensor([-0.9977], requires_grad=True), '480': Parameter containing:
#  tensor([2.4625], requires_grad=True), '481': Parameter containing:
#  tensor([1.0763], requires_grad=True), '482': Parameter containing:
#  tensor([0.2669], requires_grad=True), '483': Parameter containing:
#  tensor([-0.8568], requires_grad=True), '484': Parameter containing:
#  tensor([-0.9172], requires_grad=True), '485': Parameter containing:
#  tensor([2.4795], requires_grad=True), '486': Parameter containing:
#  tensor([-0.5278], requires_grad=True), '487': Parameter containing:
#  tensor([0.4963], requires_grad=True), '488': Parameter containing:
#  tensor([-0.9906], requires_grad=True), '489': Parameter containing:
#  tensor([-1.4755], requires_grad=True), '490': Parameter containing:
#  tensor([-1.0929], requires_grad=True), '491': Parameter containing:
#  tensor([0.3126], requires_grad=True), '492': Parameter containing:
#  tensor([-0.0461], requires_grad=True), '493': Parameter containing:
#  tensor([-0.1102], requires_grad=True), '494': Parameter containing:
#  tensor([-0.5276], requires_grad=True), '495': Parameter containing:
#  tensor([0.7375], requires_grad=True), '496': Parameter containing:
#  tensor([-0.1293], requires_grad=True), '497': Parameter containing:
#  tensor([-0.7859], requires_grad=True), '498': Parameter containing:
#  tensor([-1.2394], requires_grad=True), '499': Parameter containing:
#  tensor([-1.5913], requires_grad=True), '500': Parameter containing:
#  tensor([0.7933], requires_grad=True), '501': Parameter containing:
#  tensor([1.2417], requires_grad=True), '502': Parameter containing:
#  tensor([-0.4240], requires_grad=True), '503': Parameter containing:
#  tensor([0.4874], requires_grad=True), '504': Parameter containing:
#  tensor([-0.4005], requires_grad=True), '505': Parameter containing:
#  tensor([-0.2227], requires_grad=True), '506': Parameter containing:
#  tensor([0.1347], requires_grad=True), '507': Parameter containing:
#  tensor([-0.4393], requires_grad=True), '508': Parameter containing:
#  tensor([-0.0894], requires_grad=True), '509': Parameter containing:
#  tensor([-0.7015], requires_grad=True), '510': Parameter containing:
#  tensor([0.8791], requires_grad=True), '511': Parameter containing:
#  tensor([-0.3098], requires_grad=True), '512': Parameter containing:
#  tensor([0.2429], requires_grad=True), '513': Parameter containing:
#  tensor([0.5162], requires_grad=True), '514': Parameter containing:
#  tensor([-0.3980], requires_grad=True), '515': Parameter containing:
#  tensor([-1.3357], requires_grad=True), '516': Parameter containing:
#  tensor([1.1011], requires_grad=True), '517': Parameter containing:
#  tensor([-0.4777], requires_grad=True), '518': Parameter containing:
#  tensor([2.6556], requires_grad=True), '519': Parameter containing:
#  tensor([-0.0248], requires_grad=True), '520': Parameter containing:
#  tensor([-0.7865], requires_grad=True), '521': Parameter containing:
#  tensor([2.3222], requires_grad=True), '522': Parameter containing:
#  tensor([-0.5902], requires_grad=True), '523': Parameter containing:
#  tensor([0.9040], requires_grad=True), '524': Parameter containing:
#  tensor([-0.0300], requires_grad=True), '525': Parameter containing:
#  tensor([0.0712], requires_grad=True), '526': Parameter containing:
#  tensor([0.3724], requires_grad=True), '527': Parameter containing:
#  tensor([-0.7902], requires_grad=True), '528': Parameter containing:
#  tensor([0.2084], requires_grad=True), '529': Parameter containing:
#  tensor([-0.6984], requires_grad=True), '530': Parameter containing:
#  tensor([-0.0243], requires_grad=True), '531': Parameter containing:
#  tensor([1.5008], requires_grad=True), '532': Parameter containing:
#  tensor([-0.1966], requires_grad=True), '533': Parameter containing:
#  tensor([0.3690], requires_grad=True), '534': Parameter containing:
#  tensor([-0.1498], requires_grad=True), '535': Parameter containing:
#  tensor([2.0359], requires_grad=True), '536': Parameter containing:
#  tensor([0.6822], requires_grad=True), '537': Parameter containing:
#  tensor([-1.3678], requires_grad=True), '538': Parameter containing:
#  tensor([1.3889], requires_grad=True), '539': Parameter containing:
#  tensor([-0.6663], requires_grad=True), '540': Parameter containing:
#  tensor([1.2549], requires_grad=True), '541': Parameter containing:
#  tensor([-0.5278], requires_grad=True), '542': Parameter containing:
#  tensor([-0.0882], requires_grad=True), '543': Parameter containing:
#  tensor([-1.0891], requires_grad=True), '544': Parameter containing:
#  tensor([-1.8562], requires_grad=True), '545': Parameter containing:
#  tensor([-0.0001], requires_grad=True), '546': Parameter containing:
#  tensor([-0.3558], requires_grad=True), '547': Parameter containing:
#  tensor([-1.0472], requires_grad=True), '548': Parameter containing:
#  tensor([1.3691], requires_grad=True), '549': Parameter containing:
#  tensor([0.2273], requires_grad=True), '550': Parameter containing:
#  tensor([-0.2718], requires_grad=True), '551': Parameter containing:
#  tensor([-2.7061], requires_grad=True), '552': Parameter containing:
#  tensor([-2.6744], requires_grad=True), '553': Parameter containing:
#  tensor([-0.5353], requires_grad=True), '554': Parameter containing:
#  tensor([0.3372], requires_grad=True), '555': Parameter containing:
#  tensor([0.1317], requires_grad=True), '556': Parameter containing:
#  tensor([0.2564], requires_grad=True), '557': Parameter containing:
#  tensor([-0.0486], requires_grad=True), '558': Parameter containing:
#  tensor([0.8800], requires_grad=True), '559': Parameter containing:
#  tensor([-0.6271], requires_grad=True), '560': Parameter containing:
#  tensor([-0.8827], requires_grad=True), '561': Parameter containing:
#  tensor([0.8741], requires_grad=True), '562': Parameter containing:
#  tensor([0.1613], requires_grad=True), '563': Parameter containing:
#  tensor([0.9859], requires_grad=True), '564': Parameter containing:
#  tensor([-1.1341], requires_grad=True), '565': Parameter containing:
#  tensor([-1.4091], requires_grad=True), '566': Parameter containing:
#  tensor([-1.1702], requires_grad=True), '567': Parameter containing:
#  tensor([-1.6704], requires_grad=True), '568': Parameter containing:
#  tensor([-1.0148], requires_grad=True), '569': Parameter containing:
#  tensor([-0.6359], requires_grad=True), '570': Parameter containing:
#  tensor([-1.0288], requires_grad=True), '571': Parameter containing:
#  tensor([-1.6645], requires_grad=True), '572': Parameter containing:
#  tensor([0.6588], requires_grad=True), '573': Parameter containing:
#  tensor([0.9450], requires_grad=True), '574': Parameter containing:
#  tensor([-0.6127], requires_grad=True), '575': Parameter containing:
#  tensor([0.0553], requires_grad=True), '576': Parameter containing:
#  tensor([0.2706], requires_grad=True), '577': Parameter containing:
#  tensor([0.0573], requires_grad=True), '578': Parameter containing:
#  tensor([0.4147], requires_grad=True), '579': Parameter containing:
#  tensor([-0.5635], requires_grad=True), '580': Parameter containing:
#  tensor([1.0570], requires_grad=True), '581': Parameter containing:
#  tensor([0.1106], requires_grad=True), '582': Parameter containing:
#  tensor([-0.0776], requires_grad=True), '583': Parameter containing:
#  tensor([-1.0921], requires_grad=True), '584': Parameter containing:
#  tensor([-0.8983], requires_grad=True), '585': Parameter containing:
#  tensor([0.3279], requires_grad=True), '586': Parameter containing:
#  tensor([-0.4183], requires_grad=True), '587': Parameter containing:
#  tensor([1.7087], requires_grad=True), '588': Parameter containing:
#  tensor([-1.3259], requires_grad=True), '589': Parameter containing:
#  tensor([0.5332], requires_grad=True), '590': Parameter containing:
#  tensor([-0.5274], requires_grad=True), '591': Parameter containing:
#  tensor([1.7042], requires_grad=True), '592': Parameter containing:
#  tensor([-0.2815], requires_grad=True), '593': Parameter containing:
#  tensor([0.6855], requires_grad=True), '594': Parameter containing:
#  tensor([-1.6104], requires_grad=True), '595': Parameter containing:
#  tensor([-0.2905], requires_grad=True), '596': Parameter containing:
#  tensor([-0.2009], requires_grad=True), '597': Parameter containing:
#  tensor([-0.8343], requires_grad=True), '598': Parameter containing:
#  tensor([-0.5302], requires_grad=True), '599': Parameter containing:
#  tensor([-0.9400], requires_grad=True), '600': Parameter containing:
#  tensor([1.4946], requires_grad=True), '601': Parameter containing:
#  tensor([-0.7499], requires_grad=True), '602': Parameter containing:
#  tensor([-0.0105], requires_grad=True), '603': Parameter containing:
#  tensor([0.4382], requires_grad=True), '604': Parameter containing:
#  tensor([-0.1496], requires_grad=True), '605': Parameter containing:
#  tensor([0.8277], requires_grad=True), '606': Parameter containing:
#  tensor([1.3501], requires_grad=True), '607': Parameter containing:
#  tensor([-0.0200], requires_grad=True), '608': Parameter containing:
#  tensor([0.2332], requires_grad=True), '609': Parameter containing:
#  tensor([0.4501], requires_grad=True), '610': Parameter containing:
#  tensor([0.1465], requires_grad=True), '611': Parameter containing:
#  tensor([1.7888], requires_grad=True), '612': Parameter containing:
#  tensor([-1.6084], requires_grad=True), '613': Parameter containing:
#  tensor([1.1051], requires_grad=True), '614': Parameter containing:
#  tensor([0.6231], requires_grad=True), '615': Parameter containing:
#  tensor([-0.2823], requires_grad=True), '616': Parameter containing:
#  tensor([-0.5921], requires_grad=True), '617': Parameter containing:
#  tensor([-0.5092], requires_grad=True), '618': Parameter containing:
#  tensor([-0.3977], requires_grad=True), '619': Parameter containing:
#  tensor([0.5629], requires_grad=True), '620': Parameter containing:
#  tensor([0.4629], requires_grad=True), '621': Parameter containing:
#  tensor([-0.1993], requires_grad=True), '622': Parameter containing:
#  tensor([0.5976], requires_grad=True), '623': Parameter containing:
#  tensor([-1.6274], requires_grad=True), '624': Parameter containing:
#  tensor([1.1146], requires_grad=True), '625': Parameter containing:
#  tensor([-0.6062], requires_grad=True), '626': Parameter containing:
#  tensor([-0.1051], requires_grad=True), '627': Parameter containing:
#  tensor([-0.1757], requires_grad=True), '628': Parameter containing:
#  tensor([0.9523], requires_grad=True), '629': Parameter containing:
#  tensor([-1.6456], requires_grad=True), '630': Parameter containing:
#  tensor([-2.7303], requires_grad=True), '631': Parameter containing:
#  tensor([-1.3777], requires_grad=True), '632': Parameter containing:
#  tensor([-0.0297], requires_grad=True), '633': Parameter containing:
#  tensor([0.5614], requires_grad=True), '634': Parameter containing:
#  tensor([-0.5133], requires_grad=True), '635': Parameter containing:
#  tensor([0.9080], requires_grad=True), '636': Parameter containing:
#  tensor([-1.5862], requires_grad=True), '637': Parameter containing:
#  tensor([-0.2221], requires_grad=True), '638': Parameter containing:
#  tensor([2.0746], requires_grad=True), '639': Parameter containing:
#  tensor([-1.0731], requires_grad=True), '640': Parameter containing:
#  tensor([-1.0078], requires_grad=True), '641': Parameter containing:
#  tensor([0.5580], requires_grad=True), '642': Parameter containing:
#  tensor([0.9805], requires_grad=True), '643': Parameter containing:
#  tensor([-0.4013], requires_grad=True), '644': Parameter containing:
#  tensor([-0.4870], requires_grad=True), '645': Parameter containing:
#  tensor([0.4882], requires_grad=True), '646': Parameter containing:
#  tensor([-0.1163], requires_grad=True), '647': Parameter containing:
#  tensor([0.4513], requires_grad=True), '648': Parameter containing:
#  tensor([-2.0428], requires_grad=True), '649': Parameter containing:
#  tensor([0.7375], requires_grad=True), '650': Parameter containing:
#  tensor([1.4408], requires_grad=True), '651': Parameter containing:
#  tensor([-0.8650], requires_grad=True), '652': Parameter containing:
#  tensor([0.9300], requires_grad=True), '653': Parameter containing:
#  tensor([-0.7709], requires_grad=True), '654': Parameter containing:
#  tensor([0.1813], requires_grad=True), '655': Parameter containing:
#  tensor([1.7748], requires_grad=True), '656': Parameter containing:
#  tensor([-0.6314], requires_grad=True), '657': Parameter containing:
#  tensor([-0.4898], requires_grad=True), '658': Parameter containing:
#  tensor([0.9649], requires_grad=True), '659': Parameter containing:
#  tensor([0.6063], requires_grad=True), '660': Parameter containing:
#  tensor([-0.9289], requires_grad=True), '661': Parameter containing:
#  tensor([-1.7984], requires_grad=True), '662': Parameter containing:
#  tensor([0.0748], requires_grad=True), '663': Parameter containing:
#  tensor([0.7592], requires_grad=True), '664': Parameter containing:
#  tensor([1.2890], requires_grad=True), '665': Parameter containing:
#  tensor([1.0258], requires_grad=True), '666': Parameter containing:
#  tensor([1.4213], requires_grad=True), '667': Parameter containing:
#  tensor([1.5148], requires_grad=True), '668': Parameter containing:
#  tensor([0.4036], requires_grad=True), '669': Parameter containing:
#  tensor([0.0302], requires_grad=True), '670': Parameter containing:
#  tensor([-0.3112], requires_grad=True), '671': Parameter containing:
#  tensor([0.4006], requires_grad=True), '672': Parameter containing:
#  tensor([1.1905], requires_grad=True), '673': Parameter containing:
#  tensor([2.1552], requires_grad=True), '674': Parameter containing:
#  tensor([-0.7798], requires_grad=True), '675': Parameter containing:
#  tensor([1.1019], requires_grad=True), '676': Parameter containing:
#  tensor([-0.3535], requires_grad=True), '677': Parameter containing:
#  tensor([0.5826], requires_grad=True), '678': Parameter containing:
#  tensor([0.7041], requires_grad=True), '679': Parameter containing:
#  tensor([0.3850], requires_grad=True), '680': Parameter containing:
#  tensor([1.6059], requires_grad=True), '681': Parameter containing:
#  tensor([0.8850], requires_grad=True), '682': Parameter containing:
#  tensor([-0.8173], requires_grad=True), '683': Parameter containing:
#  tensor([2.1610], requires_grad=True), '684': Parameter containing:
#  tensor([0.4305], requires_grad=True), '685': Parameter containing:
#  tensor([0.4925], requires_grad=True), '686': Parameter containing:
#  tensor([-0.2985], requires_grad=True), '687': Parameter containing:
#  tensor([1.5641], requires_grad=True), '688': Parameter containing:
#  tensor([1.4445], requires_grad=True), '689': Parameter containing:
#  tensor([0.3719], requires_grad=True), '690': Parameter containing:
#  tensor([-1.3565], requires_grad=True), '691': Parameter containing:
#  tensor([-0.4750], requires_grad=True), '692': Parameter containing:
#  tensor([-0.0092], requires_grad=True), '693': Parameter containing:
#  tensor([1.3967], requires_grad=True), '694': Parameter containing:
#  tensor([0.9417], requires_grad=True), '695': Parameter containing:
#  tensor([-0.3566], requires_grad=True), '696': Parameter containing:
#  tensor([-2.4101], requires_grad=True), '697': Parameter containing:
#  tensor([0.1318], requires_grad=True), '698': Parameter containing:
#  tensor([0.4270], requires_grad=True), '699': Parameter containing:
#  tensor([-0.0295], requires_grad=True), '700': Parameter containing:
#  tensor([0.6181], requires_grad=True), '701': Parameter containing:
# ...
#  tensor([0.5879], requires_grad=True), '768': Parameter containing:
#  tensor([-1.4699], requires_grad=True), '769': Parameter containing:
#  tensor([-0.4241], requires_grad=True), '770': Parameter containing:
#  tensor([-0.3995], requires_grad=True), '771': Parameter containing:
#  tensor([0.7208], requires_grad=True), '772': Parameter containing:
#  tensor([-1.2243], requires_grad=True), '773': Parameter containing:
#  tensor([0.0740], requires_grad=True), '774': Parameter containing:
#  tensor([0.7331], requires_grad=True), '775': Parameter containing:
#  tensor([-2.1961], requires_grad=True), '776': Parameter containing:
#  tensor([-0.8510], requires_grad=True), '777': Parameter containing:
#  tensor([-0.3550], requires_grad=True), '778': Parameter containing:
#  tensor([0.4107], requires_grad=True), '779': Parameter containing:
#  tensor([-0.5464], requires_grad=True), '780': Parameter containing:
#  tensor([0.1139], requires_grad=True), '781': Parameter containing:
#  tensor([1.9241], requires_grad=True), '782': Parameter containing:
#  tensor([1.5041], requires_grad=True), '783': Parameter containing:
#  tensor([0.8950], requires_grad=True), '784': Parameter containing:
#  tensor([-2.2480], requires_grad=True), '785': Parameter containing:
#  tensor([1.3913], requires_grad=True), '786': Parameter containing:
#  tensor([0.6143], requires_grad=True), '787': Parameter containing:
#  tensor([0.4541], requires_grad=True), '788': Parameter containing:
#  tensor([0.2374], requires_grad=True), '789': Parameter containing:
#  tensor([1.5385], requires_grad=True), '790': Parameter containing:
#  tensor([-0.4963], requires_grad=True), '791': Parameter containing:
#  tensor([2.2675], requires_grad=True), '792': Parameter containing:
#  tensor([-1.8832], requires_grad=True), '793': Parameter containing:
#  tensor([-1.0247], requires_grad=True), '794': Parameter containing:
#  tensor([-0.8034], requires_grad=True), '795': Parameter containing:
#  tensor([0.3410], requires_grad=True), '796': Parameter containing:
#  tensor([-0.2352], requires_grad=True), '797': Parameter containing:
#  tensor([-0.6171], requires_grad=True), '798': Parameter containing:
#  tensor([-0.0618], requires_grad=True), '799': Parameter containing:
#  tensor([-1.3750], requires_grad=True), '800': Parameter containing:
#  tensor([0.0426], requires_grad=True), '801': Parameter containing:
#  tensor([-1.4513], requires_grad=True), '802': Parameter containing:
#  tensor([0.4476], requires_grad=True), '803': Parameter containing:
#  tensor([-0.4658], requires_grad=True), '804': Parameter containing:
#  tensor([0.7013], requires_grad=True), '805': Parameter containing:
#  tensor([-0.4043], requires_grad=True), '806': Parameter containing:
#  tensor([-0.9334], requires_grad=True), '807': Parameter containing:
#  tensor([0.1917], requires_grad=True), '808': Parameter containing:
#  tensor([-1.4244], requires_grad=True), '809': Parameter containing:
#  tensor([1.0996], requires_grad=True), '810': Parameter containing:
#  tensor([3.1204], requires_grad=True), '811': Parameter containing:
#  tensor([0.5219], requires_grad=True), '812': Parameter containing:
#  tensor([-0.0695], requires_grad=True), '813': Parameter containing:
#  tensor([0.4654], requires_grad=True), '814': Parameter containing:
#  tensor([-0.5258], requires_grad=True), '815': Parameter containing:
#  tensor([-0.7497], requires_grad=True), '816': Parameter containing:
#  tensor([-0.1165], requires_grad=True), '817': Parameter containing:
#  tensor([0.6617], requires_grad=True), '818': Parameter containing:
#  tensor([-0.9862], requires_grad=True), '819': Parameter containing:
#  tensor([1.5896], requires_grad=True), '820': Parameter containing:
#  tensor([-0.0332], requires_grad=True), '821': Parameter containing:
#  tensor([-0.0950], requires_grad=True), '822': Parameter containing:
#  tensor([0.5496], requires_grad=True), '823': Parameter containing:
#  tensor([0.2821], requires_grad=True), '824': Parameter containing:
#  tensor([0.2085], requires_grad=True), '825': Parameter containing:
#  tensor([-0.2389], requires_grad=True), '826': Parameter containing:
#  tensor([-1.4663], requires_grad=True), '827': Parameter containing:
#  tensor([-0.2394], requires_grad=True), '828': Parameter containing:
#  tensor([0.0263], requires_grad=True), '829': Parameter containing:
#  tensor([0.4180], requires_grad=True), '830': Parameter containing:
#  tensor([-0.0108], requires_grad=True), '831': Parameter containing:
#  tensor([-2.6229], requires_grad=True), '832': Parameter containing:
#  tensor([-0.4483], requires_grad=True), '833': Parameter containing:
#  tensor([1.2683], requires_grad=True), '834': Parameter containing:
#  tensor([-0.9074], requires_grad=True), '835': Parameter containing:
#  tensor([-1.0175], requires_grad=True), '836': Parameter containing:
#  tensor([-1.3694], requires_grad=True), '837': Parameter containing:
#  tensor([-0.7506], requires_grad=True), '838': Parameter containing:
#  tensor([0.5173], requires_grad=True), '839': Parameter containing:
#  tensor([1.0756], requires_grad=True), '840': Parameter containing:
#  tensor([-0.2559], requires_grad=True), '841': Parameter containing:
#  tensor([-1.1756], requires_grad=True), '842': Parameter containing:
#  tensor([0.2589], requires_grad=True), '843': Parameter containing:
#  tensor([0.0579], requires_grad=True), '844': Parameter containing:
#  tensor([1.7446], requires_grad=True), '845': Parameter containing:
#  tensor([1.1169], requires_grad=True), '846': Parameter containing:
#  tensor([1.0715], requires_grad=True), '847': Parameter containing:
#  tensor([0.2763], requires_grad=True), '848': Parameter containing:
#  tensor([1.4679], requires_grad=True), '849': Parameter containing:
#  tensor([0.7455], requires_grad=True), '850': Parameter containing:
#  tensor([-1.2956], requires_grad=True), '851': Parameter containing:
#  tensor([1.2893], requires_grad=True), '852': Parameter containing:
#  tensor([1.4271], requires_grad=True), '853': Parameter containing:
#  tensor([-0.6589], requires_grad=True), '854': Parameter containing:
#  tensor([0.7333], requires_grad=True), '855': Parameter containing:
#  tensor([-0.5945], requires_grad=True), '856': Parameter containing:
#  tensor([-0.3597], requires_grad=True), '857': Parameter containing:
#  tensor([-0.0410], requires_grad=True), '858': Parameter containing:
#  tensor([0.4466], requires_grad=True), '859': Parameter containing:
#  tensor([-0.8617], requires_grad=True), '860': Parameter containing:
#  tensor([0.3529], requires_grad=True), '861': Parameter containing:
#  tensor([-0.2861], requires_grad=True), '862': Parameter containing:
#  tensor([-0.4140], requires_grad=True), '863': Parameter containing:
#  tensor([-0.9214], requires_grad=True), '864': Parameter containing:
#  tensor([-0.4037], requires_grad=True), '865': Parameter containing:
#  tensor([1.4096], requires_grad=True), '866': Parameter containing:
#  tensor([0.4957], requires_grad=True), '867': Parameter containing:
#  tensor([-0.6808], requires_grad=True), '868': Parameter containing:
#  tensor([-1.5167], requires_grad=True), '869': Parameter containing:
#  tensor([-1.3075], requires_grad=True), '870': Parameter containing:
#  tensor([0.6410], requires_grad=True), '871': Parameter containing:
#  tensor([1.7536], requires_grad=True), '872': Parameter containing:
#  tensor([0.2180], requires_grad=True), '873': Parameter containing:
#  tensor([2.2696], requires_grad=True), '874': Parameter containing:
#  tensor([-1.0708], requires_grad=True), '875': Parameter containing:
#  tensor([-0.2560], requires_grad=True), '876': Parameter containing:
#  tensor([-0.6351], requires_grad=True), '877': Parameter containing:
#  tensor([1.3503], requires_grad=True), '878': Parameter containing:
#  tensor([-2.1740], requires_grad=True), '879': Parameter containing:
#  tensor([0.7700], requires_grad=True), '880': Parameter containing:
#  tensor([2.0193], requires_grad=True), '881': Parameter containing:
#  tensor([0.3128], requires_grad=True), '882': Parameter containing:
#  tensor([-0.0451], requires_grad=True), '883': Parameter containing:
#  tensor([-0.3350], requires_grad=True), '884': Parameter containing:
#  tensor([-0.3112], requires_grad=True), '885': Parameter containing:
#  tensor([1.0515], requires_grad=True), '886': Parameter containing:
#  tensor([-1.7882], requires_grad=True), '887': Parameter containing:
#  tensor([0.8664], requires_grad=True), '888': Parameter containing:
#  tensor([-1.6516], requires_grad=True), '889': Parameter containing:
#  tensor([-0.6728], requires_grad=True), '890': Parameter containing:
#  tensor([0.2518], requires_grad=True), '891': Parameter containing:
#  tensor([0.6790], requires_grad=True), '892': Parameter containing:
#  tensor([0.2413], requires_grad=True), '893': Parameter containing:
#  tensor([0.5443], requires_grad=True), '894': Parameter containing:
#  tensor([0.0187], requires_grad=True), '895': Parameter containing:
#  tensor([0.1116], requires_grad=True), '896': Parameter containing:
#  tensor([1.2326], requires_grad=True), '897': Parameter containing:
#  tensor([-1.3340], requires_grad=True), '898': Parameter containing:
#  tensor([0.0874], requires_grad=True), '899': Parameter containing:
#  tensor([-0.0579], requires_grad=True), '900': Parameter containing:
#  tensor([-0.8494], requires_grad=True), '901': Parameter containing:
#  tensor([-0.3816], requires_grad=True), '902': Parameter containing:
#  tensor([-1.4679], requires_grad=True), '903': Parameter containing:
#  tensor([-0.1401], requires_grad=True), '904': Parameter containing:
#  tensor([0.3676], requires_grad=True), '905': Parameter containing:
#  tensor([-0.4935], requires_grad=True), '906': Parameter containing:
#  tensor([0.1534], requires_grad=True), '907': Parameter containing:
#  tensor([1.6962], requires_grad=True), '908': Parameter containing:
#  tensor([-1.2240], requires_grad=True), '909': Parameter containing:
#  tensor([0.8830], requires_grad=True), '910': Parameter containing:
#  tensor([-0.4396], requires_grad=True), '911': Parameter containing:
#  tensor([0.0756], requires_grad=True), '912': Parameter containing:
#  tensor([-0.6531], requires_grad=True), '913': Parameter containing:
#  tensor([0.9163], requires_grad=True), '914': Parameter containing:
#  tensor([-0.5662], requires_grad=True), '915': Parameter containing:
#  tensor([-0.1967], requires_grad=True), '916': Parameter containing:
#  tensor([-0.2792], requires_grad=True), '917': Parameter containing:
#  tensor([0.0002], requires_grad=True), '918': Parameter containing:
#  tensor([0.5206], requires_grad=True), '919': Parameter containing:
#  tensor([0.7196], requires_grad=True), '920': Parameter containing:
#  tensor([2.6458], requires_grad=True), '921': Parameter containing:
#  tensor([-1.8205], requires_grad=True), '922': Parameter containing:
#  tensor([1.6282], requires_grad=True), '923': Parameter containing:
#  tensor([-1.3878], requires_grad=True), '924': Parameter containing:
#  tensor([-0.7537], requires_grad=True), '925': Parameter containing:
#  tensor([-0.3058], requires_grad=True), '926': Parameter containing:
#  tensor([0.1388], requires_grad=True), '927': Parameter containing:
#  tensor([-0.8315], requires_grad=True), '928': Parameter containing:
#  tensor([-0.7066], requires_grad=True), '929': Parameter containing:
#  tensor([1.1047], requires_grad=True), '930': Parameter containing:
#  tensor([-0.1268], requires_grad=True), '931': Parameter containing:
#  tensor([0.0862], requires_grad=True), '932': Parameter containing:
#  tensor([0.1921], requires_grad=True), '933': Parameter containing:
#  tensor([0.5359], requires_grad=True), '934': Parameter containing:
#  tensor([-0.9416], requires_grad=True), '935': Parameter containing:
#  tensor([0.4434], requires_grad=True), '936': Parameter containing:
#  tensor([-0.6622], requires_grad=True), '937': Parameter containing:
#  tensor([0.3244], requires_grad=True), '938': Parameter containing:
#  tensor([-0.1088], requires_grad=True), '939': Parameter containing:
#  tensor([-0.4100], requires_grad=True), '940': Parameter containing:
#  tensor([-1.9234], requires_grad=True), '941': Parameter containing:
#  tensor([-0.3421], requires_grad=True), '942': Parameter containing:
#  tensor([-0.1146], requires_grad=True), '943': Parameter containing:
#  tensor([1.1989], requires_grad=True), '944': Parameter containing:
#  tensor([0.8441], requires_grad=True), '945': Parameter containing:
#  tensor([0.5780], requires_grad=True), '946': Parameter containing:
#  tensor([0.5590], requires_grad=True), '947': Parameter containing:
#  tensor([1.2977], requires_grad=True), '948': Parameter containing:
#  tensor([-0.8871], requires_grad=True), '949': Parameter containing:
#  tensor([-1.6701], requires_grad=True), '950': Parameter containing:
#  tensor([-0.7749], requires_grad=True), '951': Parameter containing:
#  tensor([-0.8867], requires_grad=True), '952': Parameter containing:
#  tensor([0.5287], requires_grad=True), '953': Parameter containing:
#  tensor([-1.6759], requires_grad=True), '954': Parameter containing:
#  tensor([0.1795], requires_grad=True), '955': Parameter containing:
#  tensor([0.9434], requires_grad=True), '956': Parameter containing:
#  tensor([1.3031], requires_grad=True), '957': Parameter containing:
#  tensor([0.1457], requires_grad=True), '958': Parameter containing:
#  tensor([-0.9309], requires_grad=True), '959': Parameter containing:
#  tensor([0.3275], requires_grad=True), '960': Parameter containing:
#  tensor([-0.9397], requires_grad=True), '961': Parameter containing:
#  tensor([-0.3622], requires_grad=True), '962': Parameter containing:
#  tensor([0.0729], requires_grad=True), '963': Parameter containing:
#  tensor([-0.4064], requires_grad=True), '964': Parameter containing:
#  tensor([0.3303], requires_grad=True), '965': Parameter containing:
#  tensor([-2.5587], requires_grad=True), '966': Parameter containing:
#  tensor([2.1879], requires_grad=True), '967': Parameter containing:
#  tensor([-0.3131], requires_grad=True), '968': Parameter containing:
#  tensor([0.1000], requires_grad=True), '969': Parameter containing:
#  tensor([-0.5644], requires_grad=True), '970': Parameter containing:
#  tensor([1.1765], requires_grad=True), '971': Parameter containing:
#  tensor([-0.7610], requires_grad=True), '972': Parameter containing:
#  tensor([0.4459], requires_grad=True), '973': Parameter containing:
#  tensor([-1.3980], requires_grad=True), '974': Parameter containing:
#  tensor([-1.5640], requires_grad=True), '975': Parameter containing:
#  tensor([-1.4195], requires_grad=True), '976': Parameter containing:
#  tensor([-0.3764], requires_grad=True), '977': Parameter containing:
#  tensor([-0.6349], requires_grad=True), '978': Parameter containing:
#  tensor([-1.0223], requires_grad=True), '979': Parameter containing:
#  tensor([0.4661], requires_grad=True), '980': Parameter containing:
#  tensor([0.3022], requires_grad=True), '981': Parameter containing:
#  tensor([1.4285], requires_grad=True), '982': Parameter containing:
#  tensor([0.1152], requires_grad=True), '983': Parameter containing:
#  tensor([-0.1737], requires_grad=True), '984': Parameter containing:
#  tensor([0.5771], requires_grad=True), '985': Parameter containing:
#  tensor([-0.2010], requires_grad=True), '986': Parameter containing:
#  tensor([0.8794], requires_grad=True), '987': Parameter containing:
#  tensor([0.3376], requires_grad=True), '988': Parameter containing:
#  tensor([-0.2762], requires_grad=True), '989': Parameter containing:
#  tensor([0.3571], requires_grad=True), '990': Parameter containing:
#  tensor([0.4799], requires_grad=True), '991': Parameter containing:
#  tensor([0.5122], requires_grad=True), '992': Parameter containing:
#  tensor([-0.1998], requires_grad=True), '993': Parameter containing:
#  tensor([-1.3387], requires_grad=True), '994': Parameter containing:
#  tensor([-1.0307], requires_grad=True), '995': Parameter containing:
#  tensor([0.5537], requires_grad=True), '996': Parameter containing:
#  tensor([0.2861], requires_grad=True), '997': Parameter containing:
#  tensor([0.9949], requires_grad=True), '998': Parameter containing:
#  tensor([-0.6118], requires_grad=True), '999': Parameter containing:
#  tensor([-1.2638], requires_grad=True), ...}

# %%
word_to_idx
# Out:
# {'#': '0',
#  '$': '1',
#  '%': '2',
#  "''": '3',
#  '+': '4',
#  '-': '5',
#  '-1': '6',
#  '-10': '7',
#  '-2': '8',
#  '-35': '9',
#  '-55': '10',
#  '-80': '11',
#  '-axis': '12',
#  '-ed': '13',
#  '-gate': '14',
#  '-ide': '15',
#  '-ine': '16',
#  '-ol': '17',
#  '-one': '18',
#  '-patric': '19',
#  '-philic': '20',
#  '-phobic': '21',
#  '-ray': '22',
#  '-scope': '23',
#  '-self-employed/excise-tax': '24',
#  '-specific': '25',
#  '.-': '26',
#  '.a': '27',
#  '.arizona': '28',
#  '.art': '29',
#  '.attacks': '30',
#  '.brad': '31',
#  '.by': '32',
#  '.chemical': '33',
#  '.cognitive': '34',
#  '.craig': '35',
#  '.d': '36',
#  '.dan': '37',
#  '.encoding': '38',
#  '.finally': '39',
#  '.flowering': '40',
#  '.freud': '41',
#  '.high': '42',
#  '.http': '43',
#  '.if': '44',
#  '.in': '45',
#  '.instrument': '46',
#  '.iraqi': '47',
#  '.it': '48',
#  '.jack': '49',
#  '.john': '50',
#  '.jose': '51',
#  '.keyssar': '52',
#  '.kohlberg': '53',
#  '.lawrence': '54',
#  '.louis': '55',
#  '.many': '56',
#  '.miller': '57',
#  '.morgan': '58',
#  '.multiple': '59',
#  '.national': '60',
#  '.obergefell': '61',
#  '.one': '62',
#  '.other': '63',
#  '.parental': '64',
#  '.past': '65',
#  '.people': '66',
#  '.pollutionpollution': '67',
#  '.ray': '68',
#  '.richard': '69',
#  '.senator': '70',
#  '.shelby': '71',
#  '.similarly': '72',
#  '.since': '73',
#  '.social': '74',
#  '.sociologically': '75',
#  '.sometimes': '76',
#  '.studies': '77',
#  '.supercentenarians': '78',
#  '.the': '79',
#  '.there': '80',
#  '.these': '81',
#  '.this': '82',
#  '.tight': '83',
#  '.u.s': '84',
#  '.v.o': '85',
#  '.vrazfllxh': '86',
#  '.while': '87',
#  '/': '88',
#  '//abcnews.go.com/gma/video/tea-party-senator-ted-cruz-filibusters-attack-obamacare-20366644': '89',
#  '//abcnews.go.com/politics/story': '90',
#  '//blacklivesmatter.com/about/': '91',
#  '//bradblog.com/docs/fcc_zappledoctrineruling_050814.pdf': '92',
#  '//consumercomplaints.fcc.gov/hc/en-us/articles/202731600-obscene-indecent-and-profane-broadcasts': '93',
#  '//donate.naacp.org/pages/naacp-history': '94',
#  '//fivethirtyeight.com/features/broadus-effect-social-desirability-bias/': '95',
#  '//frontloading.blogspot.com/2009/02/1976-presidential-primary-calendar.html': '96',
#  '//kingencyclopedia.stanford.edu/encyclopedia/encyclopedia/enc_prayer_pilgrimage_for_freedom_1957/': '97',
#  '//lehrmaninstitute.org/history/foundingtrio.asp': '98',
#  '//millercenter.org\xad/president/biography/lincoln-impact-and-legacy': '99',
#  '//research.stlouisfed.org/fred2/series/ccussp01caq650n': '100',
#  '//research.stlouisfed.org/fred2/series/cpatax': '101',
#  '//research.stlouisfed.org/fred2/series/dexjpus': '102',
#  '//research.stlouisfed.org/fred2/series/excaus': '103',
#  '//research.stlouisfed.org/fred2/series/lrun64ttusa156s0': '104',
#  '//texaspolitics.utexas.edu/set/agreement-concealed-carry-laws-february-2015': '105',
#  '//www.aclu.org/': '106',
#  '//www.ameribev.org/': '107',
#  '//www.americanrhetoric.com/speeches/wjcoklahomabombingspeech.htm': '108',
#  '//www.austincc.edu/cppps/earlyvotingfull/report5.pdf': '109',
#  '//www.boston.com': '110',
#  '//www.cbo.gov/publication/45653': '111',
#  '//www.census.gov/hhes/www/socdemo/voting/publications/p20/2012/tables.html': '112',
#  '//www.cnn.com/2012/08/31/politics/eastwood-speech/': '113',
#  '//www.cnn.com/2013/10/01/politics/different-government-shutdowns/': '114',
#  '//www.cnn.com/transcripts/0410/15/cf.01.html': '115',
#  '//www.congress.gov/bill/111th-congress/house-bill/4872': '116',
#  '//www.constitution.org/afp/brutus02.htm': '117',
#  '//www.dailykos.com': '118',
#  '//www.deathpenaltyinfo.org/states-and-without-death-penalty': '119',
#  '//www.digitalhistory.uh.edu/active_learning/explorations/vietnam/cronkite.cfm': '120',
#  '//www.eac.gov/assets/1/workflow_staging/page/41.pdf': '121',
#  '//www.eagleton.rutgers.edu/research/documents/stalsburg-familylife-political-ambition.pdf': '122',
#  '//www.electproject.org/home/voter-turnout/voter-turnout-data': '123',
#  '//www.fcc.gov/encyclopedia/obscenity-indecency-and-profanity': '124',
#  '//www.fda.gov': '125',
#  '//www.fec.gov/disclosurehs/hsnational.do': '126',
#  '//www.fec.gov/disclosurep/pnational.do': '127',
#  '//www.fec.gov/info/publications/30year.pdf': '128',
#  '//www.fec.gov/law/litigation_cca_w.shtml': '129',
#  '//www.fec.gov/pages/bcra/bcra_update.shtml': '130',
#  '//www.fec.gov/pubrec/fe2008/tables2008.pdf': '131',
#  '//www.fjc.gov/history/home.nsf/page/courts_district.html': '132',
#  '//www.forbes.com/sites/elizabethlopatto/2014/04/29/how-many-innocent-people-are-sentenced-to-death/': '133',
#  '//www.gallup.com/poll/1600/congress-public.aspx': '134',
#  '//www.gallup.com/poll/163586/americans-approval-supreme-court-near-time-low.aspx': '135',
#  '//www.gao.gov/': '136',
#  '//www.governing.com/columns/smart-mgmt/col-is-era-unfunded-federal-mandates-over.html': '137',
#  '//www.history.com/topics/fireside-chats': '138',
#  '//www.huffingtonpost.com/2014/10/29/hurricane-sandy-second-anniversary-images_n_6054274.html': '139',
#  '//www.huffingtonpost.com/2015/04/02/lgbt-homicides_n_6993484.html': '140',
#  '//www.immigrationpolicy.org/special-reports/discrediting-': '141',
#  '//www.iop.harvard.edu/harvard-iop-fall-2015-poll': '142',
#  '//www.irs.gov/businesses/small-businesses-': '143',
#  '//www.justice.gov/about': '144',
#  '//www.justice.gov/crt/combating-religious-discrimination-and-protecting-religious-freedom-16': '145',
#  '//www.justice.gov/crt/jurisdictions-previously-covered-section-5': '146',
#  '//www.justice.gov/iso/opa/resources/3052013829132756857467.pdf': '147',
#  '//www.kssos.org/forms/communication/canvassing_kansas/dec13.pdf': '148',
#  '//www.law.cornell.edu/wex/obscenity': '149',
#  '//www.let.rug.nl/usa/documents/1786-1800/madison-speech-proposing-the-bill-of-rights-june-8-1789.php': '150',
#  '//www.msnbc.com/msnbc/gop-candidates-ban-abortion-no-exceptions': '151',
#  '//www.nbcnews.com': '152',
#  '//www.nbcwashington.com/blogs/first-read-dmv/virginia-governor-tries-to-woo-indiana-businesses-298087131.html': '153',
#  '//www.nbcwashington.com/news/local/ferguson-protests-planned-for-dc-baltimore-tuesday-283807831.html': '154',
#  '//www.ncsl.org/research/elections-and-campaigns/voter-id.aspx': '155',
#  '//www.ncsl.org/research/elections-and-campaigns/voter-list-accuracy.aspx': '156',
#  '//www.nga.org/cms/home/management-resources/governors-powers-and-authority.html': '157',
#  '//www.npr.org/sections/thetwo-way/2015/06/08/412917394/supreme-court-rejects-nra-challenge-to-s-f-gun-rules': '158',
#  '//www.nps.gov/nr/travel/wash/dc78.htm': '159',
#  '//www.nwhm.org/education-resources/biography/biographies/alice-paul/': '160',
#  '//www.nytimes.com/2011/12/10/us/redress-weighed-for-forced-sterilizations-in-north-carolina.html': '161',
#  '//www.okhistory.org/publications/enc/entry.php': '162',
#  '//www.opensecrets.org': '163',
#  '//www.opensecrets.org/overview/incumbs.php': '164',
#  '//www.opensecrets.org/pacs/': '165',
#  '//www.opensecrets.org/pacs/superpacs.php': '166',
#  '//www.opm.gov/policy-data-oversight/data-analysis-documentation/federal-employment-reports/historical-tables/total-government-employment-since-1962': '167',
#  '//www.pbs.org/newshour/rundown/forgotten-founding-father': '168',
#  '//www.pbs.org/wnet/supremecourt/antebellum/history2.html': '169',
#  '//www.people': '170',
#  '//www.people-press.org/2013/09/03/public-opinion-runs-against-syrian-airstrikes/': '171',
#  '//www.pewresearch.org': '172',
#  '//www.pewresearch.org/data-trend/domestic-issues/gun-control': '173',
#  '//www.pewresearch.org/fact-tank/2013/10/03/the-2016-presidential-media-primary-is-off-to-a-fast-start/': '174',
#  '//www.pewresearch.org/fact-tank/2014/01/13/obama-lags-his-predecessors-in-recess-appointments/': '175',
#  '//www.presidency.ucsb.edu/ws/': '176',
#  '//www.psmag.com/politics-and-law/young-people-are-not-so-politically-inclined': '177',
#  '//www.sca.isr.umich.edu': '178',
#  '//www.scholarsstrategynetwork.org/sites/default/files/ssn_basic_facts_hertel-fernandez_on_unemployment_insurance_financing.pdf': '179',
#  '//www.smithsonianmag.com': '180',
#  '//www.sos.wv.gov/public-services/execrecords/pages/pardons.aspx': '181',
#  '//www.ssa.gov/pubs/en-05-10003.pdf': '182',
#  '//www.texasobserver.org/texas-observer-exclusive-dna-tests-undermine-evidence-in-texas-execution/': '183',
#  '//www.texastribune.org/2015/06/10/abbott': '184',
#  '//www.thenewsoutlet.org/survey-local-millennials-more-interested-in-big-issues/': '185',
#  '//www.usnews.com/news/blogs/data-mine/2015/01/28/us-education-still-separate-and-unequal': '186',
#  '//www.washingtonpost.com': '187',
#  '//www.washingtonpost.com/news/post-politics/wp/2015/10/22/immigration-continues-to-be-donald-trumps-rallying-issue/.protestors': '188',
#  '//www.washingtonpost.com/news/wonk/wp/2012/12/17/everything-you-need-to-know-about-banning-assault-weapons-in-one-post/': '189',
#  '//www.washingtonpost.com/politics/great-society-agenda-led-to-great': '190',
#  '//www.washingtonpost.com/wp-dyn/content/article/2005/10/27/ar2005102700547.html': '191',
#  '//www.washingtontimes.com': '192',
#  '//www.wsj.com/articles/general-electric-plans-to-move-headquarters-to-boston-1452703676': '193',
#  '/2': '194',
#  '/flickr': '195',
#  '/s': '196',
#  '/λ': '197',
#  '0': '198',
#  '0.0': '199',
#  '0.002': '200',
#  '0.00600': '201',
#  '0.01': '202',
#  '0.012': '203',
#  '0.01ºc': '204',
#  '0.05': '205',
#  '0.1': '206',
#  '0.10': '207',
#  '0.2': '208',
#  '0.45': '209',
#  '0.5': '210',
#  '0.50': '211',
#  '0.511-mev': '212',
#  '0.7': '213',
#  '0.9': '214',
#  '002': '215',
#  '03_02_commerce': '216',
#  '08': '217',
#  '1': '218',
#  '1,000': '219',
#  '1,000,000': '220',
#  '1,093': '221',
#  '1,148,000': '222',
#  '1,219,700': '223',
#  '1,223,566.': '224',
#  '1,800': '225',
#  '1.0': '226',
#  '1.03': '227',
#  '1.045': '228',
#  '1.2': '229',
#  '1.25': '230',
#  '1.3': '231',
#  '1.4': '232',
#  '1.40': '233',
#  '1.47': '234',
#  '1.5': '235',
#  '1.63': '236',
#  '1.7': '237',
#  '1.8': '238',
#  '1.9': '239',
#  '1/10,000,000': '240',
#  '1/1000': '241',
#  '1/1800': '242',
#  '1/86,400': '243',
#  '10': '244',
#  '10,000': '245',
#  '10,000–12,000': '246',
#  '10-year': '247',
#  '10.3': '248',
#  '10.4': '249',
#  '100': '250',
#  '100,000': '251',
#  '100-point': '252',
#  '1000': '253',
#  '1000-ploid': '254',
#  '100×100×': '255',
#  '1010': '256',
#  '1012hz1012hz': '257',
#  '1019gev1019gev': '258',
#  '101st': '259',
#  '102': '260',
#  '102,552': '261',
#  '1024': '262',
#  '102–103': '263',
#  '103–160': '264',
#  '1043': '265',
#  '105–106': '266',
#  '105–131': '267',
#  '1070': '268',
#  '108': '269',
#  '109': '270',
#  '109hz109hz': '271',
#  '109–130.in': '272',
#  '10–20': '273',
#  '10−1010−10': '274',
#  '10−35m10−35': '275',
#  '10−43s10−43s': '276',
#  '10−610−6': '277',
#  '10−810−8': '278',
#  '11': '279',
#  '11,000': '280',
#  '11,790': '281',
#  '11.0': '282',
#  '110': '283',
#  '110,000': '284',
#  '111': '285',
#  '112': '286',
#  '11246': '287',
#  '113': '288',
#  '114–115': '289',
#  '115': '290',
#  '116': '291',
#  '117': '292',
#  '117,000': '293',
#  '118': '294',
#  '118,500': '295',
#  '118–120': '296',
#  '11:00': '297',
#  '12': '298',
#  '12,144,933': '299',
#  '12.0': '300',
#  '12.4': '301',
#  '12.6': '302',
#  '120': '303',
#  '120,000': '304',
#  '122': '305',
#  '124': '306',
#  '125': '307',
#  '129–166': '308',
#  '12mv212mv2': '309',
#  '12–13': '310',
#  '12–15': '311',
#  '12–22': '312',
#  '13': '313',
#  '13.2': '314',
#  '130': '315',
#  '1300': '316',
#  '1304.26': '317',
#  '1346': '318',
#  '135': '319',
#  '1361': '320',
#  '137': '321',
#  '138': '322',
#  '139': '323',
#  '13–14': '324',
#  '14': '325',
#  '14.0': '326',
#  '14.3': '327',
#  '14.4': '328',
#  '145': '329',
#  '1469': '330',
#  '146th': '331',
#  '1480': '332',
#  '1492': '333',
#  '1493': '334',
#  '14n14n': '335',
#  '15': '336',
#  '150': '337',
#  '150,000': '338',
#  '1500': '339',
#  '1500s': '340',
#  '151': '341',
#  '1517': '342',
#  '153': '343',
#  '1530': '344',
#  '1530s': '345',
#  '1540s': '346',
#  '1565': '347',
#  '158': '348',
#  '1584': '349',
#  '1590': '350',
#  '15–18': '351',
#  '16': '352',
#  '16,000': '353',
#  '16,000.now': '354',
#  '16,500': '355',
#  '16.5': '356',
#  '160': '357',
#  '160,000': '358',
#  '1600': '359',
#  '1600s': '360',
#  '161': '361',
#  '1620s': '362',
#  '1623–1662': '363',
#  '1625': '364',
#  '1626': '365',
#  '1629–1695': '366',
#  '163': '367',
#  '1637': '368',
#  '1660s': '369',
#  '1664': '370',
#  '1680s': '371',
#  '1686': '372',
#  '1688': '373',
#  '1689': '374',
#  '17': '375',
#  '17-year': '376',
#  '170': '377',
#  '1700s': '378',
#  '1700–1782': '379',
#  '171': '380',
#  '1721–1742': '381',
#  '173': '382',
#  '1730s': '383',
#  '1733': '384',
#  '1736–1806': '385',
#  '174': '386',
#  '1740s': '387',
#  '1754–1763': '388',
#  '1756–1763': '389',
#  '175–177': '390',
#  '1760s': '391',
#  '1763': '392',
#  '1764': '393',
#  '1765': '394',
#  '1766': '395',
#  '1766–1844': '396',
#  '1767': '397',
#  '1767–1832': '398',
#  '1768': '399',
#  '1770': '400',
#  '1770s': '401',
#  '1772–1823': '402',
#  '1773': '403',
#  '1774': '404',
#  '1775': '405',
#  '1775–1836': '406',
#  '1776': '407',
#  '1776–1856': '408',
#  '1777': '409',
#  '1780s': '410',
#  '1781': '411',
#  '1783': '412',
#  '1784': '413',
#  '1786': '414',
#  '1787': '415',
#  '1787—likely': '416',
#  '1789': '417',
#  '1790': '418',
#  '1791': '419',
#  '1791–1862': '420',
#  '1793': '421',
#  '1794': '422',
#  '1795': '423',
#  '1796': '424',
#  '1796–1832': '425',
#  '1797–1878': '426',
#  '1798': '427',
#  '1798–1800': '428',
#  '1799–1869': '429',
#  '17–18': '430',
#  '18': '431',
#  '18,000': '432',
#  '18-year': '433',
#  '180': '434',
#  '180,000': '435',
#  '180/100=9/5.180/100=9/5': '436',
#  '1800': '437',
#  '1800s': '438',
#  '1803': '439',
#  '1803–1853': '440',
#  '1804': '441',
#  '1804–1865': '442',
#  '1805': '443',
#  '1807': '444',
#  '181': '445',
#  '1811': '446',
#  '1812': '447',
#  '1815': '448',
#  '1816': '449',
#  '1817': '450',
#  '1818–1883': '451',
#  '1818–1889': '452',
#  '1819': '453',
#  '1820': '454',
#  '1820s': '455',
#  '1820–1903': '456',
#  '1823': '457',
#  '1824': '458',
#  '1825': '459',
#  '1828': '460',
#  '182–191': '461',
#  '1830': '462',
#  '1830s': '463',
#  '1831': '464',
#  '1832': '465',
#  '1832–1920': '466',
#  '1833': '467',
#  '1834': '468',
#  '1834–1907': '469',
#  '1835': '470',
#  '1836': '471',
#  '184': '472',
#  '1840': '473',
#  '1840s': '474',
#  '1840–1910': '475',
#  '1842–1910': '476',
#  '1844': '477',
#  '1845': '478',
#  '1846': '479',
#  '1848': '480',
#  '1848–1861': '481',
#  '1849–1936': '482',
#  '185': '483',
#  '1850': '484',
#  '1850s': '485',
#  '1853': '486',
#  '1853–1930': '487',
#  '1854': '488',
#  '1855': '489',
#  '1856': '490',
#  '1856–1939': '491',
#  '1857': '492',
#  '1858': '493',
#  '1858–1915': '494',
#  '1859': '495',
#  '186': '496',
#  '1860': '497',
#  '1860s': '498',
#  '1860–1865': '499',
#  '1861': '500',
#  '1862': '501',
#  '1863': '502',
#  '1863–1931': '503',
#  '1864': '504',
#  '1864–1929': '505',
#  '1865': '506',
#  '1865–1877': '507',
#  '1865–1943': '508',
#  '1866': '509',
#  '1867': '510',
#  '1868': '511',
#  '1869': '512',
#  '187': '513',
#  '1870': '514',
#  '1870s': '515',
#  '1870–1930': '516',
#  '1871': '517',
#  '1872': '518',
#  '1873': '519',
#  '1874/1886': '520',
#  '1876': '521',
#  '1877': '522',
#  '1878–1958': '523',
#  '1879': '524',
#  '1879.the': '525',
#  '1879–1880': '526',
#  '1880s': '527',
#  '1881–1955': '528',
#  '1882': '529',
#  '1883': '530',
#  '1883–1884': '531',
#  '1883–1946': '532',
#  '1884': '533',
#  '1885': '534',
#  '1885–1962': '535',
#  '1886': '536',
#  '1887': '537',
#  '1888': '538',
#  '1889–1890': '539',
#  '1889–1953': '540',
#  '1890': '541',
#  '1890s': '542',
#  '1891': '543',
#  '1892': '544',
#  '1893': '545',
#  '1894': '546',
#  '1895': '547',
#  '1896': '548',
#  '1897': '549',
#  '1898': '550',
#  '1899': '551',
#  '18th': '552',
#  '18–29': '553',
#  '19': '554',
#  '19,500': '555',
#  '19-year': '556',
#  '190': '557',
#  '1900': '558',
#  '1900s': '559',
#  '1901': '560',
#  '1901–1958': '561',
#  '1902': '562',
#  '1902–1987': '563',
#  '1902–1994': '564',
#  '1903': '565',
#  '1904': '566',
#  '1904–1978': '567',
#  '1904–1990': '568',
#  '1905': '569',
#  '1906': '570',
#  '1907': '571',
#  '1908': '572',
#  '1908–1970': '573',
#  '1909': '574',
#  '1910': '575',
#  '1910s': '576',
#  '1910–1985': '577',
#  '1910–2003': '578',
#  '1911': '579',
#  '1912': '580',
#  '1912–2006': '581',
#  '1913': '582',
#  '1914': '583',
#  '1915': '584',
#  '1916': '585',
#  '1917': '586',
#  '1918': '587',
#  '1918–1988': '588',
#  '1918—a': '589',
#  '1919': '590',
#  '1920': '591',
#  '1920s': '592',
#  '1920s.': '593',
#  '1920–1921': '594',
#  '1920–21': '595',
#  '1920—and': '596',
#  '1921': '597',
#  '1922': '598',
#  '1922–1982': '599',
#  '1923': '600',
#  '1924': '601',
#  '1924.an': '602',
#  '1925': '603',
#  '1927': '604',
#  '1927–1987': '605',
#  '1928': '606',
#  '1929': '607',
#  '1929–1939': '608',
#  '1930': '609',
#  '1930s': '610',
#  '1930—which': '611',
#  '1931': '612',
#  '1932': '613',
#  '1933': '614',
#  '1934': '615',
#  '1935': '616',
#  '1936': '617',
#  '1937': '618',
#  '1939': '619',
#  '1939—or': '620',
#  '1940': '621',
#  '1940s': '622',
#  '1941': '623',
#  '1942': '624',
#  '1943': '625',
#  '1944': '626',
#  '1945': '627',
#  '1946': '628',
#  '1947': '629',
#  '1947—commonly': '630',
#  '1948': '631',
#  '1949': '632',
#  '1950': '633',
#  '1950s': '634',
#  '1950–1980': '635',
#  '1951': '636',
#  '1952': '637',
#  '1953': '638',
#  '1954': '639',
#  '1954.brown': '640',
#  '1955': '641',
#  '1955–1956': '642',
#  '1956': '643',
#  '1957': '644',
#  '1958': '645',
#  '1959': '646',
#  '1960': '647',
#  '1960s': '648',
#  '1960–2012': '649',
#  '1961': '650',
#  '1962': '651',
#  '1963': '652',
#  '1964': '653',
#  '1965': '654',
#  '1965.shelby': '655',
#  '1966': '656',
#  '1967': '657',
#  '1968': '658',
#  '1969': '659',
#  '1969–1974': '660',
#  '1970': '661',
#  '1970s': '662',
#  '1970–1972': '663',
#  '1970—but': '664',
#  '1971': '665',
#  '1972': '666',
#  '1973': '667',
#  '1974': '668',
#  '1974–1975': '669',
#  '1975': '670',
#  '1976': '671',
#  '1977': '672',
#  '1978': '673',
#  '1979': '674',
#  '198': '675',
#  '1980': '676',
#  '1980.the': '677',
#  '1980s': '678',
#  '1980–1982': '679',
#  '1980–2000': '680',
#  '1980–2013these': '681',
#  '1981': '682',
#  '1981–1989': '683',
#  '1982': '684',
#  '1983': '685',
#  '1984': '686',
#  '1985': '687',
#  '1986': '688',
#  '1987': '689',
#  '1988': '690',
#  '1988.south': '691',
#  '1988—a': '692',
#  '1989': '693',
#  '1989–1990': '694',
#  '1990': '695',
#  '1990-era': '696',
#  '1990.united': '697',
#  '1990s': '698',
#  '1990–2003': '699',
#  '1990–91': '700',
#  '1991': '701',
#  '1991.gallup': '702',
#  '1992': '703',
#  '1993': '704',
#  '1994': '705',
#  '1995': '706',
#  '1996': '707',
#  '1997': '708',
#  '1997–1998': '709',
#  '1998': '710',
#  '1999': '711',
#  '19th': '712',
#  '1:2:1': '713',
#  '1n': '714',
#  '1s': '715',
#  '1s22s1': '716',
#  '1–3': '717',
#  '1–32': '718',
#  '1–5': '719',
#  '1′': '720',
#  '2': '721',
#  '2,000': '722',
#  '2,296,000': '723',
#  '2,500': '724',
#  '2-': '725',
#  '2-d': '726',
#  '2-nm': '727',
#  '2.0': '728',
#  '2.2': '729',
#  '2.25': '730',
#  '2.3': '731',
#  '2.5': '732',
#  '2.7': '733',
#  '2.9': '734',
#  '20': '735',
#  '20,000': '736',
#  '20,810': '737',
#  '20-ounce': '738',
#  '20.4': '739',
#  '200': '740',
#  '200,000': '741',
#  '200,000.nownes': '742',
#  '2000': '743',
#  '2000s': '744',
#  '2001': '745',
#  '2002': '746',
#  '2003': '747',
#  '2004': '748',
#  '2005': '749',
#  '2005.bob': '750',
#  '2005.thomas': '751',
#  '2006': '752',
#  '2007': '753',
#  '2007–2009': '754',
#  '2008': '755',
#  '2008–2009': '756',
#  '2009': '757',
#  '2009b': '758',
#  '2010': '759',
#  '2011': '760',
#  '2011d': '761',
#  '2012': '762',
#  '2012.': '763',
#  '2012.protectionism': '764',
#  '2012b': '765',
#  '2013': '766',
#  '2013a': '767',
#  '2013eitc': '768',
#  '2014': '769',
#  '2014.another': '770',
#  '2014.dilger': '771',
#  '2014.pork': '772',
#  '2014.summary': '773',
#  '2014a': '774',
#  '2014b': '775',
#  '2015': '776',
#  '2015—the': '777',
#  '2016': '778',
#  '2017': '779',
#  '2017.other': '780',
#  '2018': '781',
#  '2020': '782',
#  '2024': '783',
#  '203': '784',
#  '2030': '785',
#  '205': '786',
#  '20th': '787',
#  '20ºc20ºc': '788',
#  '20–25': '789',
#  '20–250': '790',
#  '21': '791',
#  '21-year': '792',
#  '212': '793',
#  '214': '794',
#  '215': '795',
#  '21–24': '796',
#  '22': '797',
#  '22–32': '798',
#  '23': '799',
#  '23.2this': '800',
#  '230': '801',
#  '232': '802',
#  '237': '803',
#  '238': '804',
#  '24': '805',
#  '24-hour': '806',
#  '24.0': '807',
#  '240': '808',
#  '241': '809',
#  '243': '810',
#  '247': '811',
#  '249': '812',
#  '25': '813',
#  '25,240': '814',
#  '25-year': '815',
#  '25-ω25-ω': '816',
#  '250': '817',
#  '250,000': '818',
#  '251': '819',
#  '254': '820',
#  '256': '821',
#  '257': '822',
#  '26': '823',
#  '26.6': '824',
#  '260': '825',
#  '260,000': '826',
#  '262': '827',
#  '263–264': '828',
#  '265': '829',
#  '2652': '830',
#  '266': '831',
#  '27': '832',
#  '27-year': '833',
#  '270': '834',
#  '271': '835',
#  '273': '836',
#  '273.16': '837',
#  '274': '838',
#  '274.7': '839',
#  '28': '840',
#  '28,000': '841',
#  '28.9': '842',
#  '283': '843',
#  '285': '844',
#  '29': '845',
#  '29,000': '846',
#  '29.9': '847',
#  '294': '848',
#  '295': '849',
#  '2:1': '850',
#  '2n': '851',
#  '2nd': '852',
#  '2s': '853',
#  '2′': '854',
#  '3': '855',
#  "3'-oh": '856',
#  '3,500': '857',
#  '3-pga': '858',
#  '3.2': '859',
#  '3.24': '860',
#  '3.26': '861',
#  '3.5': '862',
#  '3.8': '863',
#  '30': '864',
#  '30,000': '865',
#  '300': '866',
#  '300,000': '867',
#  '300–400': '868',
#  '301': '869',
#  '302': '870',
#  '303': '871',
#  '306': '872',
#  '30s': '873',
#  '31': '874',
#  '310': '875',
#  '311': '876',
#  '312': '877',
#  '315': '878',
#  '316': '879',
#  '317': '880',
#  '319': '881',
#  '32': '882',
#  '32,000': '883',
#  '320': '884',
#  '320/40': '885',
#  '323': '886',
#  '325,800': '887',
#  '328': '888',
#  '330': '889',
#  '332': '890',
#  '334': '891',
#  '34': '892',
#  '347': '893',
#  '35': '894',
#  '350': '895',
#  '35–40': '896',
#  '36': '897',
#  '363,053': '898',
#  '367': '899',
#  '369th': '900',
#  '36–43': '901',
#  '37': '902',
#  '370': '903',
#  '373': '904',
#  '374': '905',
#  '376': '906',
#  '379': '907',
#  '38': '908',
#  '380': '909',
#  '380–450': '910',
#  '381': '911',
#  '383': '912',
#  '384': '913',
#  '39': '914',
#  '393': '915',
#  '395': '916',
#  '397': '917',
#  '398': '918',
#  '3:00': '919',
#  '3:1': '920',
#  '3co2': '921',
#  '3rubp': '922',
#  '3–6': '923',
#  '3′': '924',
#  '4': '925',
#  '4,000': '926',
#  '4-base': '927',
#  '4.4': '928',
#  '4.5': '929',
#  '4.6': '930',
#  '4.8': '931',
#  '40': '932',
#  '40,000': '933',
#  '40-year': '934',
#  '400': '935',
#  '400,000': '936',
#  '400/80': '937',
#  '4000': '938',
#  '401': '939',
#  '403': '940',
#  '406': '941',
#  '408': '942',
#  '40s': '943',
#  '41': '944',
#  '410': '945',
#  '413': '946',
#  '414': '947',
#  '419': '948',
#  '42': '949',
#  '424': '950',
#  '428': '951',
#  '429': '952',
#  '429–441': '953',
#  '43': '954',
#  '43,000': '955',
#  '43,903': '956',
#  '43.8': '957',
#  '432': '958',
#  '436': '959',
#  '437': '960',
#  '438': '961',
#  '44': '962',
#  '443': '963',
#  '444': '964',
#  '45': '965',
#  '45-degree': '966',
#  '450': '967',
#  '456': '968',
#  '46': '969',
#  '469': '970',
#  '47': '971',
#  '470': '972',
#  '472': '973',
#  '478': '974',
#  '479': '975',
#  '48': '976',
#  '48-hour': '977',
#  '48.3': '978',
#  '483': '979',
#  '484': '980',
#  '486': '981',
#  '489': '982',
#  '49': '983',
#  '49.4': '984',
#  '491': '985',
#  '494': '986',
#  '495': '987',
#  '496': '988',
#  '497': '989',
#  '499': '990',
#  '4–7': '991',
#  '4′': '992',
#  '5': '993',
#  "5'-gccrccaugg-3": '994',
#  '5,000': '995',
#  '5,740,000': '996',
#  '5,965': '997',
#  '5-': '998',
#  '5-httlpr': '999',
#  ...}

# %%
weights_dict[weights_tuple_to_idx()]
